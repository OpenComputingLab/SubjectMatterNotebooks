# %% [markdown]
# # Classics — Grammar
#
# In term of guaranteeing correctnes, where the grammar is regular we can automate the production declensions of nouns and conjugations of verbs.
#
# This is useful in production for redusing opportunites for error. Where the means of production are shared with learners, the ability to check declensions and conjugations for arbitrary words provides an opportunity to support curiosty driven, self-directed learning.

# %% [markdown]
# ## Inflection Patterns
#
# Find the inflection (declension / conjugation) of a given word / lemma.
#
# *(Lemma - "the canonical form of an inflected word".)*

# %%
from cltk.data.fetch import FetchCorpus
corpus_downloader = FetchCorpus('lat')
path = '/Users/tonyhirst/cltk_data/lat/text/lat_text_latin_library'

corpus_downloader.import_corpus('lat_models_cltk')

# %% [markdown]
# The morphological character of a word is encoded using a nine character code string (- is used as the null character):
#
#  	1: 	part of speech
#  		n	noun
#  		v	verb
#  		t	participle
#  		a	adjective
#  		d	adverb
#  		c	conjunction
#  		r	preposition
#  		p	pronoun
#  		m	numeral
#  		i	interjection
#  		e	exclamation
#  		u	punctuation
#  	2: 	person
#  		1	first person
#  		2	second person
#  		3	third person
#  	3: 	number
#  		s	singular
#  		p	plural
#  	4: 	tense
#  		p	present
#  		i	imperfect
#  		r	perfect
#  		l	pluperfect
#  		t	future perfect
#  		f	future
#  	5: 	mood
#  		i	indicative
#  		s	subjunctive
#  		n	infinitive
#  		m	imperative
#  		p	participle
#  		d	gerund
#  		g	gerundive
#  		u	supine
#  	6: 	voice
#  		a	active
#  		p	passive
#  	7:	gender
#  		m	masculine
#  		f	feminine
#  		n	neuter
#  	8: 	case
#  		n	nominative
#  		g	genitive
#  		d	dative
#  		a	accusative
#  		b	ablative
#  		v	vocative
#  		l	locative
#  	9: 	degree
#  		c	comparative
#  		s	superlative
#
# Via: https://github.com/cltk/latin_treebank_perseus#readme

# %%
from cltk.morphology.lat import CollatinusDecliner
decliner = CollatinusDecliner()

decliner.decline("amo")[:20]
# Out:
# [('amo', 'v1spia---'),
#  ('amas', 'v2spia---'),
#  ('amat', 'v3spia---'),
#  ('amamus', 'v1ppia---'),
#  ('amatis', 'v2ppia---'),
#  ('amant', 'v3ppia---'),
#  ('amabam', 'v1siia---'),
#  ('amabas', 'v2siia---'),
#  ('amabat', 'v3siia---'),
#  ('amabamus', 'v1piia---'),
#  ('amabatis', 'v2piia---'),
#  ('amabant', 'v3piia---'),
#  ('amabo', 'v1sfia---'),
#  ('amabis', 'v2sfia---'),
#  ('amabit', 'v3sfia---'),
#  ('amabimus', 'v1pfia---'),
#  ('amabitis', 'v2pfia---'),
#  ('amabunt', 'v3pfia---'),
#  ('amavi', 'v1sria---'),
#  ('amavisti', 'v2sria---')]

# %%
decliner.decline("canis")
# Out:
# [('canis', '--s----n-'),
#  ('canis', '--s----v-'),
#  ('canem', '--s----a-'),
#  ('canis', '--s----g-'),
#  ('cani', '--s----d-'),
#  ('cane', '--s----b-'),
#  ('canes', '--p----n-'),
#  ('canes', '--p----v-'),
#  ('canes', '--p----a-'),
#  ('canum', '--p----g-'),
#  ('canibus', '--p----d-'),
#  ('canibus', '--p----b-')]

# %% [markdown]
# We can decode the strings to more easily describe the morphological character of a word.

# %%
#Taken from https://github.com/alpheios-project/pyperseus-treebank/blob/master/pyperseus_treebank/latin.py#L44#
#Maybe use https://github.com/jazzband/inflect for natural language code2text description?
import re

# Conversion table for CONLL
# Thanks to @epageperron
#??Some divergence from README?
_CONLL_LA_CONV_DICT = { "a": "adjective", "c": "conjunction",
                        "d": "adverb", "e": "exclamation", "g": "PART",
                        "i": "interjection", "l": "DET",
                        "m": "numeral", "n": "noun","p": "pronoun",
                        "r": "preposition", "t": "VERB", "u": "punctuation",
                        "v": "verb", "x": "X" }

_NUMBER = {"s": "singular", "p": "plural"}
_TENSE = {"p": "present", "f": "future", "r": "perfect", "l": "pluperfect",
          "i": "imperfect", "t": "future perfect"}
_MOOD = {"i": "indicative", "s": "subjunctive", "m": "imperative", 'd':'gerund',
         "g": "gerundive", "p": "participle", "u": "supine", "n": "infinitive"}
_VOICE = {"a": "active", "p": "passive", "d": "Dep"}
_GENDER = {"f": "feminine", "m": "masculine", "n": "neuter", "c": "Com"}
_CASE = {"g": "genitive", "d": "dative", "a": "accusative", "v": "vocative",
         "n": "nominative", "b": "ablative", "i": "Ins", "l": "locative"}
_DEGREE = {"p": "Pos", "c": "comparative", "s": "superlative"}

_PERSON = {"1":'first person', "2":'second person', "3":'third person'}

NOTWORD = re.compile("^\W+$")

_NULL_CHAR="-"

def parse_features(features):
    """ Parse features from the POSTAG of Perseus Latin XML
    .. example :: self.parse_features("n-p---na-")
    :param features: A string containing morphological informations
    :type features: str
    :return: Parsed features
    :rtype: dict
    """

    if features is None or features.lower()=='unk':
        return {}
    
    features = features.lower()
    
    feats = {}

    feats['POS'] = _CONLL_LA_CONV_DICT[features[0]]

    # Person handling : 3 possibilities
    if features[1] != _NULL_CHAR:
        feats["Person"] = _PERSON[features[1]]

    # Number handling : two possibilities
    if features[2] != _NULL_CHAR:
        feats["Number"] = _NUMBER[features[2]]

    # Tense
    if features[3] != _NULL_CHAR:
        feats["Tense"] = _TENSE[features[3]]

    # Mood
    if features[4] != _NULL_CHAR:
        feats["Mood"] = _MOOD[features[4]]

    # Voice
    if features[5] != _NULL_CHAR:
        feats["Voice"] = _VOICE[features[5]]

    # Tense
    if features[6] != _NULL_CHAR:
        feats["Gender"] = _GENDER[features[6]]

    # Tense
    if features[7] != _NULL_CHAR:
        feats["Case"] = _CASE[features[7]]

    # Degree
    if features[8] != _NULL_CHAR:
        feats["Degree"] = _DEGREE[features[8]]

    return feats

# %% [markdown]
# We can then decode the morphological data
# feature string:

# %%
#Example
parse_features('v3plia---')
# Out:
# {'POS': 'verb',
#  'Person': 'third person',
#  'Number': 'plural',
#  'Tense': 'pluperfect',
#  'Mood': 'indicative',
#  'Voice': 'active'}

# %% [markdown]
# Looking up words in the decliner provides a way of getting the morphological data for a word. For example, we could look up amabitis and get back something like `('amo', 'v2pfia---')`:

# %%
#hacky way that assumes you know the root
def lookupInflection(word, lemma):
    ''' Find the inflection of a given word, given its lemma. '''
    result=[]
    if lemma is None:
        return result
    
    lemma = [lemma] if isinstance(lemma,str) else lemma
    for l in lemma:
        try:
            words = decliner.decline(l)
            result.append([(w,d) for w,d in words if w==word])
        except:
            result.append((l, None))
    return result

# %% [markdown]
# If we know the root, we can lookup the inflection:

# %%
lookupInflection('amabitis','amo')

# %% [markdown]
# Let's see if we can find the root of a word with a simple lemmatizer:

# %%
#Lemmatizer - find root of a word
from cltk.stem.lemma import LemmaReplacer

from cltk.stem.latin.j_v import JVReplacer

#Lemmatizer requires the following
CorpusImporter('latin').import_corpus('latin_pos_lemmata_cltk')
CorpusImporter('latin').import_corpus('latin_models_cltk')


sentence = 'Progeniem sed enim Troiano a sanguine duci audierat'

sentence = sentence.lower()

lemmatizer = LemmaReplacer('latin')

lemmatizer.lemmatize(sentence)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-02294ae87891> in <module>
#       1 #Lemmatizer - find root of a word
# ----> 2 from cltk.stem.lemma import LemmaReplacer
#       3
#       4 from cltk.stem.latin.j_v import JVReplacer
#       5
#
# ModuleNotFoundError: No module named 'cltk.stem.lemma'

# %%
from cltk.lemmatize.lat import LatinBackoffLemmatizer

sentence = 'Progeniem sed enim Troiano a sanguine duci audierat'

sentence = sentence.lower()

LatinBackoffLemmatizer.lemmatize(sentence)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-8be41a33cdd3> in <module>
#       5 sentence = sentence.lower()
#       6
# ----> 7 LatinBackoffLemmatizer.lemmatize(sentence)
#
# TypeError: lemmatize() missing 1 required positional argument: 'tokens'

# %%
from cltk.lemmatize.lat import RomanNumeralLemmatizer

#Lemmatizer for identifying roman numerals in Latin text based on regex.
lemmatizer = RomanNumeralLemmatizer()

lemmatizer.lemmatize("i ii iii iv v vi vii vii ix x xx xxx xl l lx c cc".split())
# Out:
# [('i', 'NUM'),
#  ('ii', 'NUM'),
#  ('iii', 'NUM'),
#  ('iv', 'NUM'),
#  ('v', 'NUM'),
#  ('vi', 'NUM'),
#  ('vii', 'NUM'),
#  ('vii', 'NUM'),
#  ('ix', 'NUM'),
#  ('x', 'NUM'),
#  ('xx', 'NUM'),
#  ('xxx', 'NUM'),
#  ('xl', 'NUM'),
#  ('l', 'NUM'),
#  ('lx', 'NUM'),
#  ('c', 'NUM'),
#  ('cc', 'NUM')]

# %% [markdown]
# ## Syllables
#
# One way of helping students read a text is to split the syllables out.m

# %%
with open(f'{path}/vergil/aen1.txt') as f:
    aeneid_1 = f.read()

# %%
#Here's a manual way of doing a concordance, though we need to clean it for the tokeniser?
from cltk.alphabet.text_normalization import remove_non_ascii
from cltk.alphabet.text_normalization import remove_non_latin

aen1_clean = remove_non_ascii(aeneid_1)
aen1_clean = remove_non_latin(aen1_clean)
print(aen1_clean[:1000])
# Out:
# Vergil Aeneid I        P VERGILI MARONIS AENEIDOS LIBER PRIMVS  Arma virumque cano Troiae qui primus ab oris Italiam fato profugus Laviniaque venit litora multum ille et terris iactatus et alto vi superum saevae memorem Iunonis ob iram multa quoque et bello passus dum conderet urbem     inferretque deos Latio genus unde Latinum Albanique patres atque altae moenia Romae  Musa mihi causas memora quo numine laeso quidve dolens regina deum tot volvere casus insignem pietate virum tot adire labores     impulerit Tantaene animis caelestibus irae  Urbs antiqua fuit Tyrii tenuere coloni Karthago Italiam contra Tiberinaque longe ostia dives opum studiisque asperrima belli quam Iuno fertur terris magis omnibus unam     posthabita coluisse Samo hic illius arma hic currus fuit hoc regnum dea gentibus esse si qua fata sinant iam tum tenditque fovetque Progeniem sed enim Troiano a sanguine duci audierat Tyrias olim quae verteret arces     hinc populum late regem belloque superbum venturum excidio Li

# %%
from cltk.tokenizers.lat.lat import LatinWordTokenizer
from nltk.text import Text

latin_word_tokenizer = LatinWordTokenizer()

tokens = latin_word_tokenizer.tokenize(aen1_clean)
textList = Text(tokens)
textList.concordance('Libyae')
# Out:
# Displaying 7 of 7 matches:
# ello -que superbum venturum excidio Libyae sic volvere Parcas Id metuens veter
# a litora cursu contendunt petere et Libyae vertuntur ad oras Est in secessu lo
# ulos sic vertice caeli constitit et Libyae defixit lumina regnis Atque illum t
# e per aera magnum remigio alarum ac Libyae citus adstitit oris Et iam iussa fa
# o -que supersunt Ipse ignotus egens Libyae deserta peragro Europa atque Asia p
# e pater optime Teucrum pontus habet Libyae nec spes iam restat Iuli at freta S
# uidem per litora certos dimittam et Libyae lustrare extrema iubebo si quibus e

# %%
from cltk.languages.example_texts import get_example_text

example_lat = get_example_text('lat')
example_lat
# Out:
# 'Gallia est omnis divisa in partes tres, quarum unam incolunt Belgae, aliam Aquitani, tertiam qui ipsorum lingua Celtae, nostra Galli appellantur. Hi omnes lingua, institutis, legibus inter se differunt. Gallos ab Aquitanis Garumna flumen, a Belgis Matrona et Sequana dividit. Horum omnium fortissimi sunt Belgae, propterea quod a cultu atque humanitate provinciae longissime absunt, minimeque ad eos mercatores saepe commeant atque ea quae ad effeminandos animos pertinent important, proximique sunt Germanis, qui trans Rhenum incolunt, quibuscum continenter bellum gerunt. Qua de causa Helvetii quoque reliquos Gallos virtute praecedunt, quod fere cotidianis proeliis cum Germanis contendunt, cum aut suis finibus eos prohibent aut ipsi in eorum finibus bellum gerunt. Eorum una, pars, quam Gallos obtinere dictum est, initium capit a flumine Rhodano, continetur Garumna flumine, Oceano, finibus Belgarum, attingit etiam ab Sequanis et Helvetiis flumen Rhenum, vergit ad septentriones. Belgae ab extremis Galliae finibus oriuntur, pertinent ad inferiorem partem fluminis Rheni, spectant in septentrionem et orientem solem. Aquitania a Garumna flumine ad Pyrenaeos montes et eam partem Oceani quae est ad Hispaniam pertinet; spectat inter occasum solis et septentriones.'

# %%
from cltk.sentence.lat import LatinPunktSentenceTokenizer

latin_splitter = LatinPunktSentenceTokenizer()

sentences = latin_splitter.tokenize(example_lat)

sentences
# Out:
# ['Gallia est omnis divisa in partes tres, quarum unam incolunt Belgae, aliam Aquitani, tertiam qui ipsorum lingua Celtae, nostra Galli appellantur.',
#  'Hi omnes lingua, institutis, legibus inter se differunt.',
#  'Gallos ab Aquitanis Garumna flumen, a Belgis Matrona et Sequana dividit.',
#  'Horum omnium fortissimi sunt Belgae, propterea quod a cultu atque humanitate provinciae longissime absunt, minimeque ad eos mercatores saepe commeant atque ea quae ad effeminandos animos pertinent important, proximique sunt Germanis, qui trans Rhenum incolunt, quibuscum continenter bellum gerunt.',
#  'Qua de causa Helvetii quoque reliquos Gallos virtute praecedunt, quod fere cotidianis proeliis cum Germanis contendunt, cum aut suis finibus eos prohibent aut ipsi in eorum finibus bellum gerunt.',
#  'Eorum una, pars, quam Gallos obtinere dictum est, initium capit a flumine Rhodano, continetur Garumna flumine, Oceano, finibus Belgarum, attingit etiam ab Sequanis et Helvetiis flumen Rhenum, vergit ad septentriones.',
#  'Belgae ab extremis Galliae finibus oriuntur, pertinent ad inferiorem partem fluminis Rheni, spectant in septentrionem et orientem solem.',
#  'Aquitania a Garumna flumine ad Pyrenaeos montes et eam partem Oceani quae est ad Hispaniam pertinet; spectat inter occasum solis et septentriones.']

# %%
from cltk.prosody.lat.syllabifier import Syllabifier

syllabifier = Syllabifier()

clean_sentence = remove_non_ascii(remove_non_latin(sentences[0])).lower()

#Extract syllables for each word
for word in latin_word_tokenizer.tokenize(clean_sentence):
    syllables = syllabifier.syllabify(word)
    print(word, syllables)
# Out:
# gallia ['gal', 'li', 'a']
# est ['est']
# omnis ['om', 'nis']
# divisa ['di', 'vi', 'sa']
# in ['in']
# partes ['par', 'tes']
# tres ['tres']
# quarum ['qua', 'rum']
# unam ['u', 'nam']
# incolunt ['in', 'co', 'lunt']
# belgae ['bel', 'gae']
# aliam ['a', 'li', 'am']
# aquitani ['a', 'qui', 'ta', 'ni']
# tertiam ['ter', 'ti', 'am']
# qui ['qui']
# ipsorum ['ip', 'so', 'rum']
# lingua ['lin', 'gua']
# celtae ['cel', 'tae']
# nostra ['nos', 'tra']
# galli ['gal', 'li']
# appellantur ['ap', 'pel', 'lan', 'tur']

# %%
from cltk import NLP
cltk_nlp = NLP(language="lat")

# First run, prompts to allow download of Stanza NLP library models
# to ~/stanza_resources/la/ (~250MB)
# Also word embedding models from the Fasttext project to
# ~/cltk_data/lat/embeddings/fasttext 365MB
# Also Lewis's *An Elementary Latin Dictionary* (1890)
cltk_doc = cltk_nlp.analyze(text=example_lat)
# Out:
# ‎𐤀 CLTK version '1.0.14'.
# Pipeline for language 'Latin' (ISO: 'lat'): `LatinNormalizeProcess`, `LatinStanzaProcess`, `LatinEmbeddingsProcess`, `StopsProcess`, `LatinNERProcess`, `LatinLexiconProcess`.
# From `from_ud():` Number[psor]: Unrecognized UD feature name

# %%
dir(cltk_doc)
# Out:
# ['__annotations__',
#  '__class__',
#  '__dataclass_fields__',
#  '__dataclass_params__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_words_attribute',
#  'embeddings',
#  'embeddings_model',
#  'language',
#  'lemmata',
#  'morphosyntactic_features',
#  'normalized_text',
#  'pipeline',
#  'pos',
#  'raw',
#  'sentences',
#  'sentences_strings',
#  'sentences_tokens',
#  'stanza_doc',
#  'stems',
#  'tokens',
#  'tokens_stops_filtered',
#  'words']

# %%
cltk_doc.stanza_doc
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "Gallia",
#       "lemma": "iallius",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casA|gen2",
#       "feats": "Case=Nom|Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=0|end_char=6"
#     },
#     {
#       "id": 2,
#       "text": "est",
#       "lemma": "sum",
#       "upos": "AUX",
#       "xpos": "N3|modA|tem1|gen6",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 1,
#       "deprel": "cop",
#       "misc": "start_char=7|end_char=10"
#     },
#     {
#       "id": 3,
#       "text": "omnis",
#       "lemma": "omnis",
#       "upos": "DET",
#       "xpos": "C1|grn1|casA|gen2",
#       "feats": "Case=Nom|Gender=Fem|Number=Sing|PronType=Ind",
#       "head": 1,
#       "deprel": "det",
#       "misc": "start_char=11|end_char=16"
#     },
#     {
#       "id": 4,
#       "text": "divisa",
#       "lemma": "digis",
#       "upos": "ADJ",
#       "xpos": "A1|grn1|casA|gen2",
#       "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#       "head": 1,
#       "deprel": "amod",
#       "misc": "start_char=17|end_char=23"
#     },
#     {
#       "id": 5,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 6,
#       "deprel": "case",
#       "misc": "start_char=24|end_char=26"
#     },
#     {
#       "id": 6,
#       "text": "partes",
#       "lemma": "pars",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casM|gen2",
#       "feats": "Case=Acc|Gender=Fem|Number=Plur",
#       "head": 4,
#       "deprel": "obl:arg",
#       "misc": "start_char=27|end_char=33"
#     },
#     {
#       "id": 7,
#       "text": "tres",
#       "lemma": "tres",
#       "upos": "NUM",
#       "xpos": "C1|grn1|casM|gen2|vgr1",
#       "feats": "Case=Acc|Gender=Fem|NumType=Card|Number=Plur",
#       "head": 6,
#       "deprel": "nummod",
#       "misc": "start_char=34|end_char=38"
#     },
#     {
#       "id": 8,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 11,
#       "deprel": "punct",
#       "misc": "start_char=38|end_char=39"
#     },
#     {
#       "id": 9,
#       "text": "quarum",
#       "lemma": "qui",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casK|gen2",
#       "feats": "Case=Gen|Gender=Fem|Number=Plur|PronType=Rel",
#       "head": 10,
#       "deprel": "nmod",
#       "misc": "start_char=40|end_char=46"
#     },
#     {
#       "id": 10,
#       "text": "unam",
#       "lemma": "unus",
#       "upos": "NUM",
#       "xpos": "F1|grn1|casD|gen2",
#       "feats": "Case=Acc|Gender=Fem|NumType=Card|Number=Sing",
#       "head": 11,
#       "deprel": "obj",
#       "misc": "start_char=47|end_char=51"
#     },
#     {
#       "id": 11,
#       "text": "incolunt",
#       "lemma": "incolo",
#       "upos": "VERB",
#       "xpos": "L3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 6,
#       "deprel": "acl:relcl",
#       "misc": "start_char=52|end_char=60"
#     },
#     {
#       "id": 12,
#       "text": "Belgae",
#       "lemma": "belgus",
#       "upos": "ADJ",
#       "xpos": "A1|grn1|casJ|gen2",
#       "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 11,
#       "deprel": "nsubj",
#       "misc": "start_char=61|end_char=67"
#     },
#     {
#       "id": 13,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 14,
#       "deprel": "punct",
#       "misc": "start_char=67|end_char=68"
#     },
#     {
#       "id": 14,
#       "text": "aliam",
#       "lemma": "alius",
#       "upos": "DET",
#       "xpos": "F1|grn1|casD|gen2",
#       "feats": "Case=Acc|Gender=Fem|Number=Sing|PronType=Ind",
#       "head": 15,
#       "deprel": "det",
#       "misc": "start_char=69|end_char=74"
#     },
#     {
#       "id": 15,
#       "text": "Aquitani",
#       "lemma": "iquitanis",
#       "upos": "ADJ",
#       "xpos": "B1|grn1|casJ|gen1",
#       "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 25,
#       "deprel": "nsubj:pass",
#       "misc": "start_char=75|end_char=83"
#     },
#     {
#       "id": 16,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 17,
#       "deprel": "punct",
#       "misc": "start_char=83|end_char=84"
#     },
#     {
#       "id": 17,
#       "text": "tertiam",
#       "lemma": "tertius",
#       "upos": "ADJ",
#       "xpos": "A1|grn1|casD|gen2",
#       "feats": "Case=Acc|Degree=Pos|Gender=Fem|NumType=Ord|Number=Sing",
#       "head": 25,
#       "deprel": "obj",
#       "misc": "start_char=85|end_char=92"
#     },
#     {
#       "id": 18,
#       "text": "qui",
#       "lemma": "qui",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casJ|gen1",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|PronType=Rel",
#       "head": 25,
#       "deprel": "nsubj",
#       "misc": "start_char=93|end_char=96"
#     },
#     {
#       "id": 19,
#       "text": "ipsorum",
#       "lemma": "ipse",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casK|gen1",
#       "feats": "Case=Gen|Gender=Masc|Number=Plur|PronType=Dem,Prs",
#       "head": 20,
#       "deprel": "nmod",
#       "misc": "start_char=97|end_char=104"
#     },
#     {
#       "id": 20,
#       "text": "lingua",
#       "lemma": "lingua",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casF|gen2",
#       "feats": "Case=Abl|Gender=Fem|Number=Sing",
#       "head": 25,
#       "deprel": "obl",
#       "misc": "start_char=105|end_char=111"
#     },
#     {
#       "id": 21,
#       "text": "Celtae",
#       "lemma": "ieltus",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casJ|gen2|vgr1",
#       "feats": "Case=Nom|Gender=Fem|Number=Plur",
#       "head": 25,
#       "deprel": "xcomp",
#       "misc": "start_char=112|end_char=118"
#     },
#     {
#       "id": 22,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 21,
#       "deprel": "punct",
#       "misc": "start_char=118|end_char=119"
#     },
#     {
#       "id": 23,
#       "text": "nostra",
#       "lemma": "noster",
#       "upos": "DET",
#       "xpos": "A1|grn1|casJ|gen2",
#       "feats": "Case=Nom|Degree=Pos|Gender=Neut|Number=Plur|Number[psor]=Plur|Person=1|Poss=Yes|PronType=Prs",
#       "head": 24,
#       "deprel": "det",
#       "misc": "start_char=120|end_char=126"
#     },
#     {
#       "id": 24,
#       "text": "Galli",
#       "lemma": "iallus",
#       "upos": "ADJ",
#       "xpos": "B1|grn1|casJ|gen1",
#       "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 25,
#       "deprel": "nsubj:pass",
#       "misc": "start_char=127|end_char=132"
#     },
#     {
#       "id": 25,
#       "text": "appellantur",
#       "lemma": "appello",
#       "upos": "VERB",
#       "xpos": "J3|modJ|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Pass",
#       "head": 11,
#       "deprel": "conj",
#       "misc": "start_char=133|end_char=144"
#     },
#     {
#       "id": 26,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=144|end_char=145"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Hi",
#       "lemma": "is",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casJ|gen1|vgr1",
#       "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Plur|PronType=Dem",
#       "head": 10,
#       "deprel": "nsubj",
#       "misc": "start_char=146|end_char=148"
#     },
#     {
#       "id": 2,
#       "text": "omnes",
#       "lemma": "omnis",
#       "upos": "DET",
#       "xpos": "C1|grn1|casJ|gen2",
#       "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Plur|PronType=Ind",
#       "head": 1,
#       "deprel": "det",
#       "misc": "start_char=149|end_char=154"
#     },
#     {
#       "id": 3,
#       "text": "lingua",
#       "lemma": "lingua",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casF|gen2",
#       "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#       "head": 10,
#       "deprel": "obl",
#       "misc": "start_char=155|end_char=161"
#     },
#     {
#       "id": 4,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 3,
#       "deprel": "punct",
#       "misc": "start_char=161|end_char=162"
#     },
#     {
#       "id": 5,
#       "text": "institutis",
#       "lemma": "instituo",
#       "upos": "VERB",
#       "xpos": "L2|modM|tem4|grp1|casO|gen2",
#       "feats": "Aspect=Perf|Case=Abl|Degree=Pos|Gender=Fem|Number=Plur|Tense=Past|VerbForm=Part|Voice=Pass",
#       "head": 10,
#       "deprel": "advcl",
#       "misc": "start_char=163|end_char=173"
#     },
#     {
#       "id": 6,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 5,
#       "deprel": "punct",
#       "misc": "start_char=173|end_char=174"
#     },
#     {
#       "id": 7,
#       "text": "legibus",
#       "lemma": "lex",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casO|gen2",
#       "feats": "Case=Abl|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 10,
#       "deprel": "obl",
#       "misc": "start_char=175|end_char=182"
#     },
#     {
#       "id": 8,
#       "text": "inter",
#       "lemma": "inter",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 9,
#       "deprel": "case",
#       "misc": "start_char=183|end_char=188"
#     },
#     {
#       "id": 9,
#       "text": "se",
#       "lemma": "se",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casM|gen2",
#       "feats": "Case=Acc|Degree=Pos|Gender=Fem|Number=Plur|PronType=Prs|Reflex=Yes",
#       "head": 10,
#       "deprel": "obl",
#       "misc": "start_char=189|end_char=191"
#     },
#     {
#       "id": 10,
#       "text": "differunt",
#       "lemma": "differo",
#       "upos": "VERB",
#       "xpos": "N3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=192|end_char=201"
#     },
#     {
#       "id": 11,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 10,
#       "deprel": "punct",
#       "misc": "start_char=201|end_char=202"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Gallos",
#       "lemma": "iallus",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casM|gen1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 12,
#       "deprel": "obj",
#       "misc": "start_char=203|end_char=209"
#     },
#     {
#       "id": 2,
#       "text": "ab",
#       "lemma": "ab",
#       "upos": "ADP",
#       "xpos": "S4|vgr2",
#       "feats": "AdpType=Prep",
#       "head": 3,
#       "deprel": "case",
#       "misc": "start_char=210|end_char=212"
#     },
#     {
#       "id": 3,
#       "text": "Aquitanis",
#       "lemma": "Aquitanis",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casO|gen1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 1,
#       "deprel": "conj",
#       "misc": "start_char=213|end_char=222"
#     },
#     {
#       "id": 4,
#       "text": "Garumna",
#       "lemma": "iarumnus",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casF|gen1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Masc|Number=Sing",
#       "head": 3,
#       "deprel": "conj",
#       "misc": "start_char=223|end_char=230"
#     },
#     {
#       "id": 5,
#       "text": "flumen",
#       "lemma": "flumen",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casD|gen3",
#       "feats": "Case=Acc|Degree=Pos|Gender=Neut|Number=Sing",
#       "head": 12,
#       "deprel": "obj",
#       "misc": "start_char=231|end_char=237"
#     },
#     {
#       "id": 6,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 12,
#       "deprel": "punct",
#       "misc": "start_char=237|end_char=238"
#     },
#     {
#       "id": 7,
#       "text": "a",
#       "lemma": "ab",
#       "upos": "ADP",
#       "xpos": "S4|vgr1",
#       "feats": "AdpType=Prep",
#       "head": 8,
#       "deprel": "case",
#       "misc": "start_char=239|end_char=240"
#     },
#     {
#       "id": 8,
#       "text": "Belgis",
#       "lemma": "belga",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casO|gen1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 12,
#       "deprel": "obl:arg",
#       "misc": "start_char=241|end_char=247"
#     },
#     {
#       "id": 9,
#       "text": "Matrona",
#       "lemma": "Matrona",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casA|gen2",
#       "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#       "head": 12,
#       "deprel": "nsubj",
#       "misc": "start_char=248|end_char=255"
#     },
#     {
#       "id": 10,
#       "text": "et",
#       "lemma": "et",
#       "upos": "CCONJ",
#       "xpos": "O4",
#       "head": 11,
#       "deprel": "cc",
#       "misc": "start_char=256|end_char=258"
#     },
#     {
#       "id": 11,
#       "text": "Sequana",
#       "lemma": "iequanus",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casA|gen2",
#       "feats": "Case=Acc|Degree=Pos|Gender=Fem|Number=Sing",
#       "head": 9,
#       "deprel": "conj",
#       "misc": "start_char=259|end_char=266"
#     },
#     {
#       "id": 12,
#       "text": "dividit",
#       "lemma": "dinido",
#       "upos": "VERB",
#       "xpos": "L3|modA|tem1|gen6",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=267|end_char=274"
#     },
#     {
#       "id": 13,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 12,
#       "deprel": "punct",
#       "misc": "start_char=274|end_char=275"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Horum",
#       "lemma": "is",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casK|gen3",
#       "feats": "Case=Gen|Degree=Pos|Gender=Neut|Number=Plur|PronType=Dem",
#       "head": 3,
#       "deprel": "nmod",
#       "misc": "start_char=276|end_char=281"
#     },
#     {
#       "id": 2,
#       "text": "omnium",
#       "lemma": "omnis",
#       "upos": "PRON",
#       "xpos": "C1|grn1|casK|gen3",
#       "feats": "Case=Gen|Degree=Pos|Gender=Neut|Number=Plur|PronType=Ind",
#       "head": 1,
#       "deprel": "det",
#       "misc": "start_char=282|end_char=288"
#     },
#     {
#       "id": 3,
#       "text": "fortissimi",
#       "lemma": "fortis",
#       "upos": "ADJ",
#       "xpos": "B1|grn3|casJ|gen1",
#       "feats": "Case=Nom|Degree=Abs|Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=289|end_char=299"
#     },
#     {
#       "id": 4,
#       "text": "sunt",
#       "lemma": "sum",
#       "upos": "AUX",
#       "xpos": "N3|modA|tem1|gen9",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 3,
#       "deprel": "cop",
#       "misc": "start_char=300|end_char=304"
#     },
#     {
#       "id": 5,
#       "text": "Belgae",
#       "lemma": "belgus",
#       "upos": "ADJ",
#       "xpos": "A1|grn1|casJ|gen2",
#       "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 3,
#       "deprel": "nsubj",
#       "misc": "start_char=305|end_char=311"
#     },
#     {
#       "id": 6,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 15,
#       "deprel": "punct",
#       "misc": "start_char=311|end_char=312"
#     },
#     {
#       "id": 7,
#       "text": "propterea",
#       "lemma": "propterea",
#       "upos": "ADV",
#       "xpos": "O4",
#       "head": 15,
#       "deprel": "mark",
#       "misc": "start_char=313|end_char=322"
#     },
#     {
#       "id": 8,
#       "text": "quod",
#       "lemma": "quod",
#       "upos": "SCONJ",
#       "xpos": "O4",
#       "head": 7,
#       "deprel": "fixed",
#       "misc": "start_char=323|end_char=327"
#     },
#     {
#       "id": 9,
#       "text": "a",
#       "lemma": "ab",
#       "upos": "ADP",
#       "xpos": "S4|vgr1",
#       "feats": "AdpType=Prep",
#       "head": 10,
#       "deprel": "case",
#       "misc": "start_char=328|end_char=329"
#     },
#     {
#       "id": 10,
#       "text": "cultu",
#       "lemma": "cultus",
#       "upos": "NOUN",
#       "xpos": "D1|grn1|casF|gen1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Masc|Number=Sing",
#       "head": 15,
#       "deprel": "obl:arg",
#       "misc": "start_char=330|end_char=335"
#     },
#     {
#       "id": 11,
#       "text": "atque",
#       "lemma": "atque",
#       "upos": "CCONJ",
#       "xpos": "O4",
#       "head": 12,
#       "deprel": "cc",
#       "misc": "start_char=336|end_char=341"
#     },
#     {
#       "id": 12,
#       "text": "humanitate",
#       "lemma": "humanitas",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casF|gen2",
#       "feats": "Case=Abl|Degree=Pos|Gender=Fem|Number=Sing",
#       "head": 10,
#       "deprel": "conj",
#       "misc": "start_char=342|end_char=352"
#     },
#     {
#       "id": 13,
#       "text": "provinciae",
#       "lemma": "proiincia",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casB|gen2|vgr1",
#       "feats": "Case=Gen|Degree=Pos|Gender=Fem|Number=Sing",
#       "head": 10,
#       "deprel": "nmod",
#       "misc": "start_char=353|end_char=363"
#     },
#     {
#       "id": 14,
#       "text": "longissime",
#       "lemma": "long",
#       "upos": "ADV",
#       "xpos": "B1|grn3|casG",
#       "feats": "Degree=Abs",
#       "head": 15,
#       "deprel": "advmod",
#       "misc": "start_char=364|end_char=374"
#     },
#     {
#       "id": 15,
#       "text": "absunt",
#       "lemma": "absum",
#       "upos": "VERB",
#       "xpos": "N3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 22,
#       "deprel": "advcl",
#       "misc": "start_char=375|end_char=381"
#     },
#     {
#       "id": 16,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 15,
#       "deprel": "punct",
#       "misc": "start_char=381|end_char=382"
#     },
#     {
#       "id": 17,
#       "text": "minimeque",
#       "lemma": "minimeque",
#       "upos": "ADV",
#       "xpos": "B1|grn3|casG",
#       "feats": "Degree=Abs",
#       "head": 22,
#       "deprel": "advmod",
#       "misc": "start_char=383|end_char=392"
#     },
#     {
#       "id": 18,
#       "text": "ad",
#       "lemma": "ad",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 19,
#       "deprel": "case",
#       "misc": "start_char=393|end_char=395"
#     },
#     {
#       "id": 19,
#       "text": "eos",
#       "lemma": "is",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casM|gen1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Plur|PronType=Dem,Prs",
#       "head": 22,
#       "deprel": "obl:arg",
#       "misc": "start_char=396|end_char=399"
#     },
#     {
#       "id": 20,
#       "text": "mercatores",
#       "lemma": "mercator",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casJ|gen1",
#       "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 22,
#       "deprel": "nsubj",
#       "misc": "start_char=400|end_char=410"
#     },
#     {
#       "id": 21,
#       "text": "saepe",
#       "lemma": "saepe",
#       "upos": "ADV",
#       "xpos": "O4",
#       "head": 22,
#       "deprel": "advmod",
#       "misc": "start_char=411|end_char=416"
#     },
#     {
#       "id": 22,
#       "text": "commeant",
#       "lemma": "commeo",
#       "upos": "VERB",
#       "xpos": "L3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 3,
#       "deprel": "advcl",
#       "misc": "start_char=417|end_char=425"
#     },
#     {
#       "id": 23,
#       "text": "atque",
#       "lemma": "atque",
#       "upos": "CCONJ",
#       "xpos": "O4",
#       "head": 32,
#       "deprel": "cc",
#       "misc": "start_char=426|end_char=431"
#     },
#     {
#       "id": 24,
#       "text": "ea",
#       "lemma": "is",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casM|gen3",
#       "feats": "Case=Acc|Degree=Pos|Gender=Neut|Number=Plur|PronType=Dem,Prs",
#       "head": 32,
#       "deprel": "nsubj",
#       "misc": "start_char=432|end_char=434"
#     },
#     {
#       "id": 25,
#       "text": "quae",
#       "lemma": "qui",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casJ|gen3|vgr1",
#       "feats": "Case=Nom|Degree=Pos|Gender=Neut|Number=Plur|PronType=Rel",
#       "head": 29,
#       "deprel": "nsubj",
#       "misc": "start_char=435|end_char=439"
#     },
#     {
#       "id": 26,
#       "text": "ad",
#       "lemma": "ad",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 27,
#       "deprel": "mark",
#       "misc": "start_char=440|end_char=442"
#     },
#     {
#       "id": 27,
#       "text": "effeminandos",
#       "lemma": "effemino",
#       "upos": "VERB",
#       "xpos": "L2|modO|grp1|casM|gen1",
#       "feats": "Aspect=Perf|Case=Acc|Degree=Pos|Gender=Masc|Number=Plur|VerbForm=Gdv|Voice=Pass",
#       "head": 29,
#       "deprel": "ccomp",
#       "misc": "start_char=443|end_char=455"
#     },
#     {
#       "id": 28,
#       "text": "animos",
#       "lemma": "animus",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casM|gen1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 27,
#       "deprel": "nsubj:pass",
#       "misc": "start_char=456|end_char=462"
#     },
#     {
#       "id": 29,
#       "text": "pertinent",
#       "lemma": "pertineo",
#       "upos": "VERB",
#       "xpos": "K3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 24,
#       "deprel": "acl:relcl",
#       "misc": "start_char=463|end_char=472"
#     },
#     {
#       "id": 30,
#       "text": "important",
#       "lemma": "importo",
#       "upos": "VERB",
#       "xpos": "J3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 24,
#       "deprel": "acl:relcl",
#       "misc": "start_char=473|end_char=482"
#     },
#     {
#       "id": 31,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 24,
#       "deprel": "punct",
#       "misc": "start_char=482|end_char=483"
#     },
#     {
#       "id": 32,
#       "text": "proximique",
#       "lemma": "proximusque",
#       "upos": "ADJ",
#       "xpos": "B1|grn1|casJ|gen1",
#       "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 22,
#       "deprel": "conj",
#       "misc": "start_char=484|end_char=494"
#     },
#     {
#       "id": 33,
#       "text": "sunt",
#       "lemma": "sum",
#       "upos": "AUX",
#       "xpos": "N3|modA|tem1|gen9",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 32,
#       "deprel": "cop",
#       "misc": "start_char=495|end_char=499"
#     },
#     {
#       "id": 34,
#       "text": "Germanis",
#       "lemma": "Germanis",
#       "upos": "ADJ",
#       "xpos": "B1|grn1|casL|gen1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 32,
#       "deprel": "nmod",
#       "misc": "start_char=500|end_char=508"
#     },
#     {
#       "id": 35,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 39,
#       "deprel": "punct",
#       "misc": "start_char=508|end_char=509"
#     },
#     {
#       "id": 36,
#       "text": "qui",
#       "lemma": "qui",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casJ|gen1",
#       "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Plur|PronType=Rel",
#       "head": 39,
#       "deprel": "nsubj",
#       "misc": "start_char=510|end_char=513"
#     },
#     {
#       "id": 37,
#       "text": "trans",
#       "lemma": "trans",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 38,
#       "deprel": "case",
#       "misc": "start_char=514|end_char=519"
#     },
#     {
#       "id": 38,
#       "text": "Rhenum",
#       "lemma": "Rhenum",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casD|gen1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Sing",
#       "head": 39,
#       "deprel": "obl",
#       "misc": "start_char=520|end_char=526"
#     },
#     {
#       "id": 39,
#       "text": "incolunt",
#       "lemma": "incolo",
#       "upos": "VERB",
#       "xpos": "L3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 34,
#       "deprel": "acl:relcl",
#       "misc": "start_char=527|end_char=535"
#     },
#     {
#       "id": 40,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 44,
#       "deprel": "punct",
#       "misc": "start_char=535|end_char=536"
#     },
#     {
#       "id": 41,
#       "text": "quibuscum",
#       "lemma": "quicumque",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casJ|gen1",
#       "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Plur|PronType=Rel",
#       "head": 44,
#       "deprel": "nsubj",
#       "misc": "start_char=537|end_char=546"
#     },
#     {
#       "id": 42,
#       "text": "continenter",
#       "lemma": "continenter",
#       "upos": "ADV",
#       "xpos": "L2|modD|tem1|grp1|casG",
#       "feats": "Degree=Pos",
#       "head": 44,
#       "deprel": "advmod",
#       "misc": "start_char=547|end_char=558"
#     },
#     {
#       "id": 43,
#       "text": "bellum",
#       "lemma": "bellum",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casD|gen3",
#       "feats": "Case=Acc|Degree=Pos|Gender=Neut|Number=Sing",
#       "head": 44,
#       "deprel": "obj",
#       "misc": "start_char=559|end_char=565"
#     },
#     {
#       "id": 44,
#       "text": "gerunt",
#       "lemma": "gero",
#       "upos": "VERB",
#       "xpos": "L3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 39,
#       "deprel": "advcl",
#       "misc": "start_char=566|end_char=572"
#     },
#     {
#       "id": 45,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 3,
#       "deprel": "punct",
#       "misc": "start_char=572|end_char=573"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Qua",
#       "lemma": "is",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casF|gen2|varA",
#       "feats": "Case=Abl|Degree=Pos|Gender=Fem|Number=Sing|PronType=Rel",
#       "head": 9,
#       "deprel": "obl",
#       "misc": "start_char=574|end_char=577"
#     },
#     {
#       "id": 2,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 3,
#       "deprel": "case",
#       "misc": "start_char=578|end_char=580"
#     },
#     {
#       "id": 3,
#       "text": "causa",
#       "lemma": "causa",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casF|gen2|vgr1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Fem|Number=Sing",
#       "head": 9,
#       "deprel": "obl",
#       "misc": "start_char=581|end_char=586"
#     },
#     {
#       "id": 4,
#       "text": "Helvetii",
#       "lemma": "ieleetium",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casB|gen1",
#       "feats": "Case=Gen|Degree=Pos|Gender=Masc|Number=Sing",
#       "head": 3,
#       "deprel": "nmod",
#       "misc": "start_char=587|end_char=595"
#     },
#     {
#       "id": 5,
#       "text": "quoque",
#       "lemma": "quoque",
#       "upos": "ADV",
#       "xpos": "O4|comQ",
#       "head": 9,
#       "deprel": "advmod",
#       "misc": "start_char=596|end_char=602"
#     },
#     {
#       "id": 6,
#       "text": "reliquos",
#       "lemma": "reliquus",
#       "upos": "DET",
#       "xpos": "F1|grn1|casM|gen1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Plur|PronType=Ind",
#       "head": 7,
#       "deprel": "det",
#       "misc": "start_char=603|end_char=611"
#     },
#     {
#       "id": 7,
#       "text": "Gallos",
#       "lemma": "iallus",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casM|gen1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 9,
#       "deprel": "obj",
#       "misc": "start_char=612|end_char=618"
#     },
#     {
#       "id": 8,
#       "text": "virtute",
#       "lemma": "eirtus",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casF|gen2",
#       "feats": "Case=Abl|Degree=Pos|Gender=Fem|Number=Sing",
#       "head": 9,
#       "deprel": "obl",
#       "misc": "start_char=619|end_char=626"
#     },
#     {
#       "id": 9,
#       "text": "praecedunt",
#       "lemma": "praecedo",
#       "upos": "VERB",
#       "xpos": "L3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=627|end_char=637"
#     },
#     {
#       "id": 10,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 17,
#       "deprel": "punct",
#       "misc": "start_char=637|end_char=638"
#     },
#     {
#       "id": 11,
#       "text": "quod",
#       "lemma": "quod",
#       "upos": "SCONJ",
#       "xpos": "O4",
#       "head": 17,
#       "deprel": "mark",
#       "misc": "start_char=639|end_char=643"
#     },
#     {
#       "id": 12,
#       "text": "fere",
#       "lemma": "fere",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 14,
#       "deprel": "case",
#       "misc": "start_char=644|end_char=648"
#     },
#     {
#       "id": 13,
#       "text": "cotidianis",
#       "lemma": "cotidianis",
#       "upos": "ADJ",
#       "xpos": "A1|grn1|casO|gen2",
#       "feats": "Case=Abl|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 14,
#       "deprel": "amod",
#       "misc": "start_char=649|end_char=659"
#     },
#     {
#       "id": 14,
#       "text": "proeliis",
#       "lemma": "proelium",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casO|gen2",
#       "feats": "Case=Abl|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 17,
#       "deprel": "obl",
#       "misc": "start_char=660|end_char=668"
#     },
#     {
#       "id": 15,
#       "text": "cum",
#       "lemma": "cum",
#       "upos": "ADP",
#       "xpos": "S4|vgr1",
#       "feats": "AdpType=Prep",
#       "head": 16,
#       "deprel": "case",
#       "misc": "start_char=669|end_char=672"
#     },
#     {
#       "id": 16,
#       "text": "Germanis",
#       "lemma": "Germanis",
#       "upos": "ADJ",
#       "xpos": "B1|grn1|casO|gen1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 17,
#       "deprel": "obl",
#       "misc": "start_char=673|end_char=681"
#     },
#     {
#       "id": 17,
#       "text": "contendunt",
#       "lemma": "contendo",
#       "upos": "VERB",
#       "xpos": "L3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 9,
#       "deprel": "advcl",
#       "misc": "start_char=682|end_char=692"
#     },
#     {
#       "id": 18,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 24,
#       "deprel": "punct",
#       "misc": "start_char=692|end_char=693"
#     },
#     {
#       "id": 19,
#       "text": "cum",
#       "lemma": "cum",
#       "upos": "SCONJ",
#       "xpos": "S4|vgr1",
#       "head": 24,
#       "deprel": "mark",
#       "misc": "start_char=694|end_char=697"
#     },
#     {
#       "id": 20,
#       "text": "aut",
#       "lemma": "aut",
#       "upos": "ADV",
#       "xpos": "O4",
#       "head": 22,
#       "deprel": "advmod:emph",
#       "misc": "start_char=698|end_char=701"
#     },
#     {
#       "id": 21,
#       "text": "suis",
#       "lemma": "suus",
#       "upos": "DET",
#       "xpos": "B1|grn1|casO|gen1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Masc|Number=Plur|Person=3|Poss=Yes|PronType=Prs|Reflex=Yes",
#       "head": 22,
#       "deprel": "det",
#       "misc": "start_char=702|end_char=706"
#     },
#     {
#       "id": 22,
#       "text": "finibus",
#       "lemma": "finis",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casO|gen1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 24,
#       "deprel": "obl",
#       "misc": "start_char=707|end_char=714"
#     },
#     {
#       "id": 23,
#       "text": "eos",
#       "lemma": "is",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casM|gen1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Plur|PronType=Dem,Prs",
#       "head": 24,
#       "deprel": "obj",
#       "misc": "start_char=715|end_char=718"
#     },
#     {
#       "id": 24,
#       "text": "prohibent",
#       "lemma": "prohibeo",
#       "upos": "VERB",
#       "xpos": "K3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 17,
#       "deprel": "advcl",
#       "misc": "start_char=719|end_char=728"
#     },
#     {
#       "id": 25,
#       "text": "aut",
#       "lemma": "aut",
#       "upos": "CCONJ",
#       "xpos": "O4",
#       "head": 31,
#       "deprel": "cc",
#       "misc": "start_char=729|end_char=732"
#     },
#     {
#       "id": 26,
#       "text": "ipsi",
#       "lemma": "ipse",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casJ|gen1",
#       "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Plur|PronType=Dem,Prs",
#       "head": 31,
#       "deprel": "nsubj",
#       "misc": "start_char=733|end_char=737"
#     },
#     {
#       "id": 27,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 29,
#       "deprel": "case",
#       "misc": "start_char=738|end_char=740"
#     },
#     {
#       "id": 28,
#       "text": "eorum",
#       "lemma": "is",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casK|gen1",
#       "feats": "Case=Gen|Degree=Pos|Gender=Masc|Number=Plur|PronType=Dem,Prs",
#       "head": 29,
#       "deprel": "nmod",
#       "misc": "start_char=741|end_char=746"
#     },
#     {
#       "id": 29,
#       "text": "finibus",
#       "lemma": "finis",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casO|gen1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 31,
#       "deprel": "obl",
#       "misc": "start_char=747|end_char=754"
#     },
#     {
#       "id": 30,
#       "text": "bellum",
#       "lemma": "bellum",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casD|gen3",
#       "feats": "Case=Acc|Degree=Pos|Gender=Neut|Number=Sing",
#       "head": 31,
#       "deprel": "obj",
#       "misc": "start_char=755|end_char=761"
#     },
#     {
#       "id": 31,
#       "text": "gerunt",
#       "lemma": "gero",
#       "upos": "VERB",
#       "xpos": "L3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 24,
#       "deprel": "conj",
#       "misc": "start_char=762|end_char=768"
#     },
#     {
#       "id": 32,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 9,
#       "deprel": "punct",
#       "misc": "start_char=768|end_char=769"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Eorum",
#       "lemma": "is",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casK|gen3",
#       "feats": "Case=Gen|Degree=Pos|Gender=Neut|Number=Plur|PronType=Dem,Prs",
#       "head": 2,
#       "deprel": "nmod",
#       "misc": "start_char=770|end_char=775"
#     },
#     {
#       "id": 2,
#       "text": "una",
#       "lemma": "unus",
#       "upos": "NUM",
#       "xpos": "F1|grn1|casA|gen2",
#       "feats": "Case=Nom|Degree=Pos|Gender=Fem|NumType=Card|Number=Sing",
#       "head": 18,
#       "deprel": "nsubj:pass",
#       "misc": "start_char=776|end_char=779"
#     },
#     {
#       "id": 3,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 4,
#       "deprel": "punct",
#       "misc": "start_char=779|end_char=780"
#     },
#     {
#       "id": 4,
#       "text": "pars",
#       "lemma": "pars",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casA|gen2",
#       "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#       "head": 2,
#       "deprel": "conj",
#       "misc": "start_char=781|end_char=785"
#     },
#     {
#       "id": 5,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 9,
#       "deprel": "punct",
#       "misc": "start_char=785|end_char=786"
#     },
#     {
#       "id": 6,
#       "text": "quam",
#       "lemma": "qui",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casD|gen2",
#       "feats": "Case=Acc|Degree=Pos|Gender=Fem|Number=Sing|PronType=Rel",
#       "head": 8,
#       "deprel": "obj",
#       "misc": "start_char=787|end_char=791"
#     },
#     {
#       "id": 7,
#       "text": "Gallos",
#       "lemma": "iallus",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casM|gen1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 8,
#       "deprel": "obj",
#       "misc": "start_char=792|end_char=798"
#     },
#     {
#       "id": 8,
#       "text": "obtinere",
#       "lemma": "obtineo",
#       "upos": "VERB",
#       "xpos": "K3|modH|tem1",
#       "feats": "Aspect=Imp|Tense=Pres|VerbForm=Inf|Voice=Act",
#       "head": 9,
#       "deprel": "xcomp",
#       "misc": "start_char=799|end_char=807"
#     },
#     {
#       "id": 9,
#       "text": "dictum",
#       "lemma": "dico",
#       "upos": "VERB",
#       "xpos": "N2|modM|tem4|grp1|casA|gen3",
#       "feats": "Aspect=Perf|Case=Nom|Degree=Pos|Gender=Neut|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass",
#       "head": 4,
#       "deprel": "acl:relcl",
#       "misc": "start_char=808|end_char=814"
#     },
#     {
#       "id": 10,
#       "text": "est",
#       "lemma": "sum",
#       "upos": "AUX",
#       "xpos": "N3|modA|tem1|gen6",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 9,
#       "deprel": "aux:pass",
#       "misc": "start_char=815|end_char=818"
#     },
#     {
#       "id": 11,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 13,
#       "deprel": "punct",
#       "misc": "start_char=818|end_char=819"
#     },
#     {
#       "id": 12,
#       "text": "initium",
#       "lemma": "initium",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casD|gen3",
#       "feats": "Case=Acc|Degree=Pos|Gender=Neut|Number=Sing",
#       "head": 13,
#       "deprel": "obj",
#       "misc": "start_char=820|end_char=827"
#     },
#     {
#       "id": 13,
#       "text": "capit",
#       "lemma": "capio",
#       "upos": "VERB",
#       "xpos": "L3|modA|tem1|gen6",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 9,
#       "deprel": "conj",
#       "misc": "start_char=828|end_char=833"
#     },
#     {
#       "id": 14,
#       "text": "a",
#       "lemma": "ab",
#       "upos": "ADP",
#       "xpos": "S4|vgr1",
#       "feats": "AdpType=Prep",
#       "head": 15,
#       "deprel": "case",
#       "misc": "start_char=834|end_char=835"
#     },
#     {
#       "id": 15,
#       "text": "flumine",
#       "lemma": "flumen",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casF|gen3",
#       "feats": "Case=Abl|Degree=Pos|Gender=Neut|Number=Sing",
#       "head": 13,
#       "deprel": "obl:arg",
#       "misc": "start_char=836|end_char=843"
#     },
#     {
#       "id": 16,
#       "text": "Rhodano",
#       "lemma": "ihodanus",
#       "upos": "ADJ",
#       "xpos": "B1|grn1|casF|gen3",
#       "feats": "Case=Abl|Degree=Pos|Gender=Neut|Number=Sing",
#       "head": 15,
#       "deprel": "amod",
#       "misc": "start_char=844|end_char=851"
#     },
#     {
#       "id": 17,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 18,
#       "deprel": "punct",
#       "misc": "start_char=851|end_char=852"
#     },
#     {
#       "id": 18,
#       "text": "continetur",
#       "lemma": "contineo",
#       "upos": "VERB",
#       "xpos": "K3|modJ|tem1|gen6",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Pass",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=853|end_char=863"
#     },
#     {
#       "id": 19,
#       "text": "Garumna",
#       "lemma": "iarumnus",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casF|gen3",
#       "feats": "Case=Abl|Degree=Pos|Gender=Neut|Number=Sing",
#       "head": 18,
#       "deprel": "obl",
#       "misc": "start_char=864|end_char=871"
#     },
#     {
#       "id": 20,
#       "text": "flumine",
#       "lemma": "flumen",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casF|gen3",
#       "feats": "Case=Abl|Degree=Pos|Gender=Neut|Number=Sing",
#       "head": 18,
#       "deprel": "obl",
#       "misc": "start_char=872|end_char=879"
#     },
#     {
#       "id": 21,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 22,
#       "deprel": "punct",
#       "misc": "start_char=879|end_char=880"
#     },
#     {
#       "id": 22,
#       "text": "Oceano",
#       "lemma": "mceanum",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casF|gen3",
#       "feats": "Case=Abl|Degree=Pos|Gender=Neut|Number=Sing",
#       "head": 20,
#       "deprel": "conj",
#       "misc": "start_char=881|end_char=887"
#     },
#     {
#       "id": 23,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 22,
#       "deprel": "punct",
#       "misc": "start_char=887|end_char=888"
#     },
#     {
#       "id": 24,
#       "text": "finibus",
#       "lemma": "finis",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casO|gen1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 27,
#       "deprel": "obl",
#       "misc": "start_char=889|end_char=896"
#     },
#     {
#       "id": 25,
#       "text": "Belgarum",
#       "lemma": "Belgarum",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casK|gen2",
#       "feats": "Case=Gen|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 24,
#       "deprel": "nmod",
#       "misc": "start_char=897|end_char=905"
#     },
#     {
#       "id": 26,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 24,
#       "deprel": "punct",
#       "misc": "start_char=905|end_char=906"
#     },
#     {
#       "id": 27,
#       "text": "attingit",
#       "lemma": "attingo",
#       "upos": "VERB",
#       "xpos": "L3|modA|tem1|gen6",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 18,
#       "deprel": "conj",
#       "misc": "start_char=907|end_char=915"
#     },
#     {
#       "id": 28,
#       "text": "etiam",
#       "lemma": "etiam",
#       "upos": "ADV",
#       "xpos": "O4|vgr1",
#       "head": 30,
#       "deprel": "advmod:emph",
#       "misc": "start_char=916|end_char=921"
#     },
#     {
#       "id": 29,
#       "text": "ab",
#       "lemma": "ab",
#       "upos": "ADP",
#       "xpos": "S4|vgr2",
#       "feats": "AdpType=Prep",
#       "head": 30,
#       "deprel": "case",
#       "misc": "start_char=922|end_char=924"
#     },
#     {
#       "id": 30,
#       "text": "Sequanis",
#       "lemma": "Sequanis",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casO|gen1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 27,
#       "deprel": "obl:arg",
#       "misc": "start_char=925|end_char=933"
#     },
#     {
#       "id": 31,
#       "text": "et",
#       "lemma": "et",
#       "upos": "CCONJ",
#       "xpos": "O4",
#       "head": 32,
#       "deprel": "cc",
#       "misc": "start_char=934|end_char=936"
#     },
#     {
#       "id": 32,
#       "text": "Helvetiis",
#       "lemma": "eeleetium",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casO|gen2",
#       "feats": "Case=Abl|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 30,
#       "deprel": "conj",
#       "misc": "start_char=937|end_char=946"
#     },
#     {
#       "id": 33,
#       "text": "flumen",
#       "lemma": "flumen",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casD|gen3",
#       "feats": "Case=Acc|Degree=Pos|Gender=Neut|Number=Sing",
#       "head": 27,
#       "deprel": "obj",
#       "misc": "start_char=947|end_char=953"
#     },
#     {
#       "id": 34,
#       "text": "Rhenum",
#       "lemma": "Rhenum",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casD|gen1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Sing",
#       "head": 33,
#       "deprel": "amod",
#       "misc": "start_char=954|end_char=960"
#     },
#     {
#       "id": 35,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 36,
#       "deprel": "punct",
#       "misc": "start_char=960|end_char=961"
#     },
#     {
#       "id": 36,
#       "text": "vergit",
#       "lemma": "iergo",
#       "upos": "VERB",
#       "xpos": "L3|modA|tem1|gen6",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 27,
#       "deprel": "conj",
#       "misc": "start_char=962|end_char=968"
#     },
#     {
#       "id": 37,
#       "text": "ad",
#       "lemma": "ad",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 38,
#       "deprel": "case",
#       "misc": "start_char=969|end_char=971"
#     },
#     {
#       "id": 38,
#       "text": "septentriones",
#       "lemma": "septentrio",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casM|gen2",
#       "feats": "Case=Acc|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 36,
#       "deprel": "obl:arg",
#       "misc": "start_char=972|end_char=985"
#     },
#     {
#       "id": 39,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 18,
#       "deprel": "punct",
#       "misc": "start_char=985|end_char=986"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Belgae",
#       "lemma": "belgus",
#       "upos": "ADJ",
#       "xpos": "A1|grn1|casJ|gen2",
#       "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 6,
#       "deprel": "nsubj",
#       "misc": "start_char=987|end_char=993"
#     },
#     {
#       "id": 2,
#       "text": "ab",
#       "lemma": "ab",
#       "upos": "ADP",
#       "xpos": "S4|vgr2",
#       "feats": "AdpType=Prep",
#       "head": 5,
#       "deprel": "case",
#       "misc": "start_char=994|end_char=996"
#     },
#     {
#       "id": 3,
#       "text": "extremis",
#       "lemma": "exterior",
#       "upos": "ADJ",
#       "xpos": "B1|grn3|casO|gen3",
#       "feats": "Case=Abl|Degree=Abs|Gender=Fem|Number=Plur",
#       "head": 5,
#       "deprel": "amod",
#       "misc": "start_char=997|end_char=1005"
#     },
#     {
#       "id": 4,
#       "text": "Galliae",
#       "lemma": "iallia",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casB|gen2",
#       "feats": "Case=Gen|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 5,
#       "deprel": "nmod",
#       "misc": "start_char=1006|end_char=1013"
#     },
#     {
#       "id": 5,
#       "text": "finibus",
#       "lemma": "finis",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casO|gen1",
#       "feats": "Case=Abl|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 6,
#       "deprel": "obl:arg",
#       "misc": "start_char=1014|end_char=1021"
#     },
#     {
#       "id": 6,
#       "text": "oriuntur",
#       "lemma": "orior",
#       "upos": "VERB",
#       "xpos": "N3|modJ|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Pass",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=1022|end_char=1030"
#     },
#     {
#       "id": 7,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 8,
#       "deprel": "punct",
#       "misc": "start_char=1030|end_char=1031"
#     },
#     {
#       "id": 8,
#       "text": "pertinent",
#       "lemma": "pertineo",
#       "upos": "VERB",
#       "xpos": "K3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 6,
#       "deprel": "conj",
#       "misc": "start_char=1032|end_char=1041"
#     },
#     {
#       "id": 9,
#       "text": "ad",
#       "lemma": "ad",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 11,
#       "deprel": "case",
#       "misc": "start_char=1042|end_char=1044"
#     },
#     {
#       "id": 10,
#       "text": "inferiorem",
#       "lemma": "inferus",
#       "upos": "ADJ",
#       "xpos": "C1|grn2|casD|gen2",
#       "feats": "Case=Acc|Degree=Cmp|Gender=Fem|Number=Sing",
#       "head": 11,
#       "deprel": "amod",
#       "misc": "start_char=1045|end_char=1055"
#     },
#     {
#       "id": 11,
#       "text": "partem",
#       "lemma": "pars",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casD|gen2",
#       "feats": "Case=Acc|Degree=Pos|Gender=Fem|Number=Sing",
#       "head": 8,
#       "deprel": "obl:arg",
#       "misc": "start_char=1056|end_char=1062"
#     },
#     {
#       "id": 12,
#       "text": "fluminis",
#       "lemma": "flumen",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casB|gen3",
#       "feats": "Case=Gen|Degree=Pos|Gender=Neut|Number=Sing",
#       "head": 11,
#       "deprel": "nmod",
#       "misc": "start_char=1063|end_char=1071"
#     },
#     {
#       "id": 13,
#       "text": "Rheni",
#       "lemma": "ihenum",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casB|gen1",
#       "feats": "Case=Gen|Degree=Pos|Gender=Masc|Number=Sing",
#       "head": 12,
#       "deprel": "nmod",
#       "misc": "start_char=1072|end_char=1077"
#     },
#     {
#       "id": 14,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 15,
#       "deprel": "punct",
#       "misc": "start_char=1077|end_char=1078"
#     },
#     {
#       "id": 15,
#       "text": "spectant",
#       "lemma": "specto",
#       "upos": "VERB",
#       "xpos": "J3|modA|tem1|gen9",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 8,
#       "deprel": "conj",
#       "misc": "start_char=1079|end_char=1087"
#     },
#     {
#       "id": 16,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 17,
#       "deprel": "case",
#       "misc": "start_char=1088|end_char=1090"
#     },
#     {
#       "id": 17,
#       "text": "septentrionem",
#       "lemma": "septentrio",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casD|gen2|vgr1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Fem|Number=Sing",
#       "head": 15,
#       "deprel": "obl:arg",
#       "misc": "start_char=1091|end_char=1104"
#     },
#     {
#       "id": 18,
#       "text": "et",
#       "lemma": "et",
#       "upos": "CCONJ",
#       "xpos": "O4",
#       "head": 19,
#       "deprel": "cc",
#       "misc": "start_char=1105|end_char=1107"
#     },
#     {
#       "id": 19,
#       "text": "orientem",
#       "lemma": "orior",
#       "upos": "VERB",
#       "xpos": "L2|modD|tem1|grp1|casD|gen1",
#       "feats": "Aspect=Imp|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing|Tense=Pres|VerbForm=Part|Voice=Act",
#       "head": 20,
#       "deprel": "acl",
#       "misc": "start_char=1108|end_char=1116"
#     },
#     {
#       "id": 20,
#       "text": "solem",
#       "lemma": "sol",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casD|gen1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Sing",
#       "head": 15,
#       "deprel": "obj",
#       "misc": "start_char=1117|end_char=1122"
#     },
#     {
#       "id": 21,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 15,
#       "deprel": "punct",
#       "misc": "start_char=1122|end_char=1123"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Aquitania",
#       "lemma": "Aquitania",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casA|gen2",
#       "feats": "Case=Nom|Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=1124|end_char=1133"
#     },
#     {
#       "id": 2,
#       "text": "a",
#       "lemma": "ab",
#       "upos": "ADP",
#       "xpos": "S4|vgr1",
#       "feats": "AdpType=Prep",
#       "head": 3,
#       "deprel": "case",
#       "misc": "start_char=1134|end_char=1135"
#     },
#     {
#       "id": 3,
#       "text": "Garumna",
#       "lemma": "iarumnus",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casF|gen3",
#       "feats": "Case=Abl|Gender=Neut|Number=Sing",
#       "head": 1,
#       "deprel": "conj",
#       "misc": "start_char=1136|end_char=1143"
#     },
#     {
#       "id": 4,
#       "text": "flumine",
#       "lemma": "flumen",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casF|gen3",
#       "feats": "Case=Abl|Gender=Neut|Number=Sing",
#       "head": 1,
#       "deprel": "conj",
#       "misc": "start_char=1144|end_char=1151"
#     },
#     {
#       "id": 5,
#       "text": "ad",
#       "lemma": "ad",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 7,
#       "deprel": "case",
#       "misc": "start_char=1152|end_char=1154"
#     },
#     {
#       "id": 6,
#       "text": "Pyrenaeos",
#       "lemma": "iyrenaeus",
#       "upos": "ADJ",
#       "xpos": "B1|grn1|casM|gen1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Plur",
#       "head": 7,
#       "deprel": "amod",
#       "misc": "start_char=1155|end_char=1164"
#     },
#     {
#       "id": 7,
#       "text": "montes",
#       "lemma": "mons",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casM|gen1",
#       "feats": "Case=Acc|Gender=Masc|Number=Plur",
#       "head": 1,
#       "deprel": "advcl",
#       "misc": "start_char=1165|end_char=1171"
#     },
#     {
#       "id": 8,
#       "text": "et",
#       "lemma": "et",
#       "upos": "CCONJ",
#       "xpos": "O4",
#       "head": 10,
#       "deprel": "cc",
#       "misc": "start_char=1172|end_char=1174"
#     },
#     {
#       "id": 9,
#       "text": "eam",
#       "lemma": "is",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casD|gen2",
#       "feats": "Case=Acc|Gender=Fem|Number=Sing|PronType=Dem,Prs",
#       "head": 10,
#       "deprel": "det",
#       "misc": "start_char=1175|end_char=1178"
#     },
#     {
#       "id": 10,
#       "text": "partem",
#       "lemma": "pars",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casD|gen2",
#       "feats": "Case=Acc|Gender=Fem|Number=Sing",
#       "head": 7,
#       "deprel": "conj",
#       "misc": "start_char=1179|end_char=1185"
#     },
#     {
#       "id": 11,
#       "text": "Oceani",
#       "lemma": "zceanum",
#       "upos": "NOUN",
#       "xpos": "B1|grn1|casB|gen3",
#       "feats": "Case=Gen|Gender=Neut|Number=Sing",
#       "head": 10,
#       "deprel": "nmod",
#       "misc": "start_char=1186|end_char=1192"
#     },
#     {
#       "id": 12,
#       "text": "quae",
#       "lemma": "qui",
#       "upos": "PRON",
#       "xpos": "F1|grn1|casA|gen2|vgr1",
#       "feats": "Case=Nom|Gender=Fem|Number=Sing|PronType=Rel",
#       "head": 13,
#       "deprel": "nsubj",
#       "misc": "start_char=1193|end_char=1197"
#     },
#     {
#       "id": 13,
#       "text": "est",
#       "lemma": "sum",
#       "upos": "VERB",
#       "xpos": "N3|modA|tem1|gen6",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 11,
#       "deprel": "acl:relcl",
#       "misc": "start_char=1198|end_char=1201"
#     },
#     {
#       "id": 14,
#       "text": "ad",
#       "lemma": "ad",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 15,
#       "deprel": "case",
#       "misc": "start_char=1202|end_char=1204"
#     },
#     {
#       "id": 15,
#       "text": "Hispaniam",
#       "lemma": "iispania",
#       "upos": "NOUN",
#       "xpos": "A1|grn1|casD|gen2|vgr1",
#       "feats": "Case=Acc|Gender=Fem|Number=Sing",
#       "head": 13,
#       "deprel": "obl",
#       "misc": "start_char=1205|end_char=1214"
#     },
#     {
#       "id": 16,
#       "text": "pertinet",
#       "lemma": "pertineo",
#       "upos": "VERB",
#       "xpos": "K3|modA|tem1|gen6",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 11,
#       "deprel": "acl:relcl",
#       "misc": "start_char=1215|end_char=1223"
#     },
#     {
#       "id": 17,
#       "text": ";",
#       "lemma": ";",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=1223|end_char=1224"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "spectat",
#       "lemma": "specto",
#       "upos": "VERB",
#       "xpos": "J3|modA|tem1|gen6",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=1225|end_char=1232"
#     },
#     {
#       "id": 2,
#       "text": "inter",
#       "lemma": "inter",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 3,
#       "deprel": "case",
#       "misc": "start_char=1233|end_char=1238"
#     },
#     {
#       "id": 3,
#       "text": "occasum",
#       "lemma": "occasum",
#       "upos": "NOUN",
#       "xpos": "D1|grn1|casD|gen1",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Sing",
#       "head": 1,
#       "deprel": "obl",
#       "misc": "start_char=1239|end_char=1246"
#     },
#     {
#       "id": 4,
#       "text": "solis",
#       "lemma": "sol",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casB|gen1",
#       "feats": "Case=Gen|Degree=Pos|Gender=Masc|Number=Sing",
#       "head": 3,
#       "deprel": "nmod",
#       "misc": "start_char=1247|end_char=1252"
#     },
#     {
#       "id": 5,
#       "text": "et",
#       "lemma": "et",
#       "upos": "CCONJ",
#       "xpos": "O4",
#       "head": 6,
#       "deprel": "cc",
#       "misc": "start_char=1253|end_char=1255"
#     },
#     {
#       "id": 6,
#       "text": "septentriones",
#       "lemma": "septentrio",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casM|gen2",
#       "feats": "Case=Acc|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 3,
#       "deprel": "conj",
#       "misc": "start_char=1256|end_char=1269"
#     },
#     {
#       "id": 7,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "Punc",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=1269|end_char=1270"
#     }
#   ]
# ]

# %%
# Also: cltk_doc.raw
cltk_doc.normalized_text
# Out:
# 'Gallia est omnis divisa in partes tres, quarum unam incolunt Belgae, aliam Aquitani, tertiam qui ipsorum lingua Celtae, nostra Galli appellantur. Hi omnes lingua, institutis, legibus inter se differunt. Gallos ab Aquitanis Garumna flumen, a Belgis Matrona et Sequana dividit. Horum omnium fortissimi sunt Belgae, propterea quod a cultu atque humanitate provinciae longissime absunt, minimeque ad eos mercatores saepe commeant atque ea quae ad effeminandos animos pertinent important, proximique sunt Germanis, qui trans Rhenum incolunt, quibuscum continenter bellum gerunt. Qua de causa Helvetii quoque reliquos Gallos virtute praecedunt, quod fere cotidianis proeliis cum Germanis contendunt, cum aut suis finibus eos prohibent aut ipsi in eorum finibus bellum gerunt. Eorum una, pars, quam Gallos obtinere dictum est, initium capit a flumine Rhodano, continetur Garumna flumine, Oceano, finibus Belgarum, attingit etiam ab Sequanis et Helvetiis flumen Rhenum, vergit ad septentriones. Belgae ab extremis Galliae finibus oriuntur, pertinent ad inferiorem partem fluminis Rheni, spectant in septentrionem et orientem solem. Aquitania a Garumna flumine ad Pyrenaeos montes et eam partem Oceani quae est ad Hispaniam pertinet; spectat inter occasum solis et septentriones.'

# %%
cltk_doc.sentences_strings
# Out:
# ['Gallia est omnis divisa in partes tres , quarum unam incolunt Belgae , aliam Aquitani , tertiam qui ipsorum lingua Celtae , nostra Galli appellantur .',
#  'Hi omnes lingua , institutis , legibus inter se differunt .',
#  'Gallos ab Aquitanis Garumna flumen , a Belgis Matrona et Sequana dividit .',
#  'Horum omnium fortissimi sunt Belgae , propterea quod a cultu atque humanitate provinciae longissime absunt , minimeque ad eos mercatores saepe commeant atque ea quae ad effeminandos animos pertinent important , proximique sunt Germanis , qui trans Rhenum incolunt , quibuscum continenter bellum gerunt .',
#  'Qua de causa Helvetii quoque reliquos Gallos virtute praecedunt , quod fere cotidianis proeliis cum Germanis contendunt , cum aut suis finibus eos prohibent aut ipsi in eorum finibus bellum gerunt .',
#  'Eorum una , pars , quam Gallos obtinere dictum est , initium capit a flumine Rhodano , continetur Garumna flumine , Oceano , finibus Belgarum , attingit etiam ab Sequanis et Helvetiis flumen Rhenum , vergit ad septentriones .',
#  'Belgae ab extremis Galliae finibus oriuntur , pertinent ad inferiorem partem fluminis Rheni , spectant in septentrionem et orientem solem .',
#  'Aquitania a Garumna flumine ad Pyrenaeos montes et eam partem Oceani quae est ad Hispaniam pertinet ;',
#  'spectat inter occasum solis et septentriones .']

# %%
cltk_doc.sentences_tokens
# Out:
# [['Gallia',
#   'est',
#   'omnis',
#   'divisa',
#   'in',
#   'partes',
#   'tres',
#   ',',
#   'quarum',
#   'unam',
#   'incolunt',
#   'Belgae',
#   ',',
#   'aliam',
#   'Aquitani',
#   ',',
#   'tertiam',
#   'qui',
#   'ipsorum',
#   'lingua',
#   'Celtae',
#   ',',
#   'nostra',
#   'Galli',
#   'appellantur',
#   '.'],
#  ['Hi',
#   'omnes',
#   'lingua',
#   ',',
#   'institutis',
#   ',',
#   'legibus',
#   'inter',
#   'se',
#   'differunt',
#   '.'],
#  ['Gallos',
#   'ab',
#   'Aquitanis',
#   'Garumna',
#   'flumen',
#   ',',
#   'a',
#   'Belgis',
#   'Matrona',
#   'et',
#   'Sequana',
#   'dividit',
#   '.'],
#  ['Horum',
#   'omnium',
#   'fortissimi',
#   'sunt',
#   'Belgae',
#   ',',
#   'propterea',
#   'quod',
#   'a',
#   'cultu',
#   'atque',
#   'humanitate',
#   'provinciae',
#   'longissime',
#   'absunt',
#   ',',
#   'minimeque',
#   'ad',
#   'eos',
#   'mercatores',
#   'saepe',
#   'commeant',
#   'atque',
#   'ea',
#   'quae',
#   'ad',
#   'effeminandos',
#   'animos',
#   'pertinent',
#   'important',
#   ',',
#   'proximique',
#   'sunt',
#   'Germanis',
#   ',',
#   'qui',
#   'trans',
#   'Rhenum',
#   'incolunt',
#   ',',
#   'quibuscum',
#   'continenter',
#   'bellum',
#   'gerunt',
#   '.'],
#  ['Qua',
#   'de',
#   'causa',
#   'Helvetii',
#   'quoque',
#   'reliquos',
#   'Gallos',
#   'virtute',
#   'praecedunt',
#   ',',
#   'quod',
#   'fere',
#   'cotidianis',
#   'proeliis',
#   'cum',
#   'Germanis',
#   'contendunt',
#   ',',
#   'cum',
#   'aut',
#   'suis',
#   'finibus',
#   'eos',
#   'prohibent',
#   'aut',
#   'ipsi',
#   'in',
#   'eorum',
#   'finibus',
#   'bellum',
#   'gerunt',
#   '.'],
#  ['Eorum',
#   'una',
#   ',',
#   'pars',
#   ',',
#   'quam',
#   'Gallos',
#   'obtinere',
#   'dictum',
#   'est',
#   ',',
#   'initium',
#   'capit',
#   'a',
#   'flumine',
#   'Rhodano',
#   ',',
#   'continetur',
#   'Garumna',
#   'flumine',
#   ',',
#   'Oceano',
#   ',',
#   'finibus',
#   'Belgarum',
#   ',',
#   'attingit',
#   'etiam',
#   'ab',
#   'Sequanis',
#   'et',
#   'Helvetiis',
#   'flumen',
#   'Rhenum',
#   ',',
#   'vergit',
#   'ad',
#   'septentriones',
#   '.'],
#  ['Belgae',
#   'ab',
#   'extremis',
#   'Galliae',
#   'finibus',
#   'oriuntur',
#   ',',
#   'pertinent',
#   'ad',
#   'inferiorem',
#   'partem',
#   'fluminis',
#   'Rheni',
#   ',',
#   'spectant',
#   'in',
#   'septentrionem',
#   'et',
#   'orientem',
#   'solem',
#   '.'],
#  ['Aquitania',
#   'a',
#   'Garumna',
#   'flumine',
#   'ad',
#   'Pyrenaeos',
#   'montes',
#   'et',
#   'eam',
#   'partem',
#   'Oceani',
#   'quae',
#   'est',
#   'ad',
#   'Hispaniam',
#   'pertinet',
#   ';'],
#  ['spectat', 'inter', 'occasum', 'solis', 'et', 'septentriones', '.']]

# %%
[ p for p in zip(cltk_doc.tokens, cltk_doc.lemmata,
                 cltk_doc.pos, cltk_doc.morphosyntactic_features)]
# Out:
# [('Gallia',
#   'iallius',
#   'NOUN',
#   {Case: [nominative], Gender: [feminine], Number: [singular]}),
#  ('est',
#   'sum',
#   'AUX',
#   {Mood: [indicative], Number: [singular], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('omnis',
#   'omnis',
#   'DET',
#   {Case: [nominative], Gender: [feminine], Number: [singular], PrononimalType: [indefinite]}),
#  ('divisa',
#   'digis',
#   'ADJ',
#   {Case: [nominative], Degree: [positive], Gender: [feminine], Number: [singular]}),
#  ('in', 'in', 'ADP', {AdpositionalType: [preposition]}),
#  ('partes',
#   'pars',
#   'NOUN',
#   {Case: [accusative], Gender: [feminine], Number: [plural]}),
#  ('tres',
#   'tres',
#   'NUM',
#   {Case: [accusative], Gender: [feminine], Numeral: [cardinal], Number: [plural]}),
#  (',', ',', 'PUNCT', {}),
#  ('quarum',
#   'qui',
#   'PRON',
#   {Case: [genitive], Gender: [feminine], Number: [plural], PrononimalType: [relative]}),
#  ('unam',
#   'unus',
#   'NUM',
#   {Case: [accusative], Gender: [feminine], Numeral: [cardinal], Number: [singular]}),
#  ('incolunt',
#   'incolo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('Belgae',
#   'belgus',
#   'ADJ',
#   {Case: [nominative], Degree: [positive], Gender: [feminine], Number: [plural]}),
#  (',', ',', 'PUNCT', {}),
#  ('aliam',
#   'alius',
#   'DET',
#   {Case: [accusative], Gender: [feminine], Number: [singular], PrononimalType: [indefinite]}),
#  ('Aquitani',
#   'iquitanis',
#   'ADJ',
#   {Case: [nominative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  (',', ',', 'PUNCT', {}),
#  ('tertiam',
#   'tertius',
#   'ADJ',
#   {Case: [accusative], Degree: [positive], Gender: [feminine], Numeral: [ordinal], Number: [singular]}),
#  ('qui',
#   'qui',
#   'PRON',
#   {Case: [nominative], Gender: [masculine], Number: [singular], PrononimalType: [relative]}),
#  ('ipsorum',
#   'ipse',
#   'PRON',
#   {Case: [genitive], Gender: [masculine], Number: [plural], PrononimalType: [demonstrative]}),
#  ('lingua',
#   'lingua',
#   'NOUN',
#   {Case: [ablative], Gender: [feminine], Number: [singular]}),
#  ('Celtae',
#   'ieltus',
#   'NOUN',
#   {Case: [nominative], Gender: [feminine], Number: [plural]}),
#  (',', ',', 'PUNCT', {}),
#  ('nostra',
#   'noster',
#   'DET',
#   {Case: [nominative], Degree: [positive], Gender: [neuter], Number: [plural], <class 'NoneType'>: [None], Person: [first], Possessive: [pos], PrononimalType: [personal]}),
#  ('Galli',
#   'iallus',
#   'ADJ',
#   {Case: [nominative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('appellantur',
#   'appello',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [passive]}),
#  ('.', '.', 'PUNCT', {}),
#  ('Hi',
#   'is',
#   'PRON',
#   {Case: [nominative], Degree: [positive], Gender: [masculine], Number: [plural], PrononimalType: [demonstrative]}),
#  ('omnes',
#   'omnis',
#   'DET',
#   {Case: [nominative], Degree: [positive], Gender: [feminine], Number: [plural], PrononimalType: [indefinite]}),
#  ('lingua',
#   'lingua',
#   'NOUN',
#   {Case: [nominative], Degree: [positive], Gender: [feminine], Number: [singular]}),
#  (',', ',', 'PUNCT', {}),
#  ('institutis',
#   'instituo',
#   'VERB',
#   {Aspect: [perfective], Case: [ablative], Degree: [positive], Gender: [feminine], Number: [plural], Tense: [past], VerbForm: [participle], Voice: [passive]}),
#  (',', ',', 'PUNCT', {}),
#  ('legibus',
#   'lex',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [feminine], Number: [plural]}),
#  ('inter', 'inter', 'ADP', {AdpositionalType: [preposition]}),
#  ('se',
#   'se',
#   'PRON',
#   {Case: [accusative], Degree: [positive], Gender: [feminine], Number: [plural], PrononimalType: [personal], Reflexive: [pos]}),
#  ('differunt',
#   'differo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('.', '.', 'PUNCT', {}),
#  ('Gallos',
#   'iallus',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('ab', 'ab', 'ADP', {AdpositionalType: [preposition]}),
#  ('Aquitanis',
#   'Aquitanis',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('Garumna',
#   'iarumnus',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [masculine], Number: [singular]}),
#  ('flumen',
#   'flumen',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [neuter], Number: [singular]}),
#  (',', ',', 'PUNCT', {}),
#  ('a', 'ab', 'ADP', {AdpositionalType: [preposition]}),
#  ('Belgis',
#   'belga',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('Matrona',
#   'Matrona',
#   'NOUN',
#   {Case: [nominative], Degree: [positive], Gender: [feminine], Number: [singular]}),
#  ('et', 'et', 'CCONJ', {}),
#  ('Sequana',
#   'iequanus',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [feminine], Number: [singular]}),
#  ('dividit',
#   'dinido',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [singular], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('.', '.', 'PUNCT', {}),
#  ('Horum',
#   'is',
#   'PRON',
#   {Case: [genitive], Degree: [positive], Gender: [neuter], Number: [plural], PrononimalType: [demonstrative]}),
#  ('omnium',
#   'omnis',
#   'PRON',
#   {Case: [genitive], Degree: [positive], Gender: [neuter], Number: [plural], PrononimalType: [indefinite]}),
#  ('fortissimi',
#   'fortis',
#   'ADJ',
#   {Case: [nominative], Degree: [absolute_superlative], Gender: [masculine], Number: [plural]}),
#  ('sunt',
#   'sum',
#   'AUX',
#   {Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('Belgae',
#   'belgus',
#   'ADJ',
#   {Case: [nominative], Degree: [positive], Gender: [feminine], Number: [plural]}),
#  (',', ',', 'PUNCT', {}),
#  ('propterea', 'propterea', 'ADV', {}),
#  ('quod', 'quod', 'SCONJ', {}),
#  ('a', 'ab', 'ADP', {AdpositionalType: [preposition]}),
#  ('cultu',
#   'cultus',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [masculine], Number: [singular]}),
#  ('atque', 'atque', 'CCONJ', {}),
#  ('humanitate',
#   'humanitas',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [feminine], Number: [singular]}),
#  ('provinciae',
#   'proiincia',
#   'NOUN',
#   {Case: [genitive], Degree: [positive], Gender: [feminine], Number: [singular]}),
#  ('longissime', 'long', 'ADV', {Degree: [absolute_superlative]}),
#  ('absunt',
#   'absum',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  (',', ',', 'PUNCT', {}),
#  ('minimeque', 'minimeque', 'ADV', {Degree: [absolute_superlative]}),
#  ('ad', 'ad', 'ADP', {AdpositionalType: [preposition]}),
#  ('eos',
#   'is',
#   'PRON',
#   {Case: [accusative], Degree: [positive], Gender: [masculine], Number: [plural], PrononimalType: [demonstrative]}),
#  ('mercatores',
#   'mercator',
#   'NOUN',
#   {Case: [nominative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('saepe', 'saepe', 'ADV', {}),
#  ('commeant',
#   'commeo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('atque', 'atque', 'CCONJ', {}),
#  ('ea',
#   'is',
#   'PRON',
#   {Case: [accusative], Degree: [positive], Gender: [neuter], Number: [plural], PrononimalType: [demonstrative]}),
#  ('quae',
#   'qui',
#   'PRON',
#   {Case: [nominative], Degree: [positive], Gender: [neuter], Number: [plural], PrononimalType: [relative]}),
#  ('ad', 'ad', 'ADP', {AdpositionalType: [preposition]}),
#  ('effeminandos',
#   'effemino',
#   'VERB',
#   {Aspect: [perfective], Case: [accusative], Degree: [positive], Gender: [masculine], Number: [plural], VerbForm: [gerundive], Voice: [passive]}),
#  ('animos',
#   'animus',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('pertinent',
#   'pertineo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('important',
#   'importo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  (',', ',', 'PUNCT', {}),
#  ('proximique',
#   'proximusque',
#   'ADJ',
#   {Case: [nominative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('sunt',
#   'sum',
#   'AUX',
#   {Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('Germanis',
#   'Germanis',
#   'ADJ',
#   {Case: [ablative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  (',', ',', 'PUNCT', {}),
#  ('qui',
#   'qui',
#   'PRON',
#   {Case: [nominative], Degree: [positive], Gender: [masculine], Number: [plural], PrononimalType: [relative]}),
#  ('trans', 'trans', 'ADP', {AdpositionalType: [preposition]}),
#  ('Rhenum',
#   'Rhenum',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [masculine], Number: [singular]}),
#  ('incolunt',
#   'incolo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  (',', ',', 'PUNCT', {}),
#  ('quibuscum',
#   'quicumque',
#   'PRON',
#   {Case: [nominative], Degree: [positive], Gender: [masculine], Number: [plural], PrononimalType: [relative]}),
#  ('continenter', 'continenter', 'ADV', {Degree: [positive]}),
#  ('bellum',
#   'bellum',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [neuter], Number: [singular]}),
#  ('gerunt',
#   'gero',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('.', '.', 'PUNCT', {}),
#  ('Qua',
#   'is',
#   'PRON',
#   {Case: [ablative], Degree: [positive], Gender: [feminine], Number: [singular], PrononimalType: [relative]}),
#  ('de', 'de', 'ADP', {AdpositionalType: [preposition]}),
#  ('causa',
#   'causa',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [feminine], Number: [singular]}),
#  ('Helvetii',
#   'ieleetium',
#   'NOUN',
#   {Case: [genitive], Degree: [positive], Gender: [masculine], Number: [singular]}),
#  ('quoque', 'quoque', 'ADV', {}),
#  ('reliquos',
#   'reliquus',
#   'DET',
#   {Case: [accusative], Degree: [positive], Gender: [masculine], Number: [plural], PrononimalType: [indefinite]}),
#  ('Gallos',
#   'iallus',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('virtute',
#   'eirtus',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [feminine], Number: [singular]}),
#  ('praecedunt',
#   'praecedo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  (',', ',', 'PUNCT', {}),
#  ('quod', 'quod', 'SCONJ', {}),
#  ('fere', 'fere', 'ADP', {AdpositionalType: [preposition]}),
#  ('cotidianis',
#   'cotidianis',
#   'ADJ',
#   {Case: [ablative], Degree: [positive], Gender: [feminine], Number: [plural]}),
#  ('proeliis',
#   'proelium',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [feminine], Number: [plural]}),
#  ('cum', 'cum', 'ADP', {AdpositionalType: [preposition]}),
#  ('Germanis',
#   'Germanis',
#   'ADJ',
#   {Case: [ablative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('contendunt',
#   'contendo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  (',', ',', 'PUNCT', {}),
#  ('cum', 'cum', 'SCONJ', {}),
#  ('aut', 'aut', 'ADV', {}),
#  ('suis',
#   'suus',
#   'DET',
#   {Case: [ablative], Degree: [positive], Gender: [masculine], Number: [plural], Person: [third], Possessive: [pos], PrononimalType: [personal], Reflexive: [pos]}),
#  ('finibus',
#   'finis',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('eos',
#   'is',
#   'PRON',
#   {Case: [accusative], Degree: [positive], Gender: [masculine], Number: [plural], PrononimalType: [demonstrative]}),
#  ('prohibent',
#   'prohibeo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('aut', 'aut', 'CCONJ', {}),
#  ('ipsi',
#   'ipse',
#   'PRON',
#   {Case: [nominative], Degree: [positive], Gender: [masculine], Number: [plural], PrononimalType: [demonstrative]}),
#  ('in', 'in', 'ADP', {AdpositionalType: [preposition]}),
#  ('eorum',
#   'is',
#   'PRON',
#   {Case: [genitive], Degree: [positive], Gender: [masculine], Number: [plural], PrononimalType: [demonstrative]}),
#  ('finibus',
#   'finis',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('bellum',
#   'bellum',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [neuter], Number: [singular]}),
#  ('gerunt',
#   'gero',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('.', '.', 'PUNCT', {}),
#  ('Eorum',
#   'is',
#   'PRON',
#   {Case: [genitive], Degree: [positive], Gender: [neuter], Number: [plural], PrononimalType: [demonstrative]}),
#  ('una',
#   'unus',
#   'NUM',
#   {Case: [nominative], Degree: [positive], Gender: [feminine], Numeral: [cardinal], Number: [singular]}),
#  (',', ',', 'PUNCT', {}),
#  ('pars',
#   'pars',
#   'NOUN',
#   {Case: [nominative], Degree: [positive], Gender: [feminine], Number: [singular]}),
#  (',', ',', 'PUNCT', {}),
#  ('quam',
#   'qui',
#   'PRON',
#   {Case: [accusative], Degree: [positive], Gender: [feminine], Number: [singular], PrononimalType: [relative]}),
#  ('Gallos',
#   'iallus',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('obtinere',
#   'obtineo',
#   'VERB',
#   {Aspect: [imperfective], Tense: [present], VerbForm: [infinitive], Voice: [active]}),
#  ('dictum',
#   'dico',
#   'VERB',
#   {Aspect: [perfective], Case: [nominative], Degree: [positive], Gender: [neuter], Number: [singular], Tense: [past], VerbForm: [participle], Voice: [passive]}),
#  ('est',
#   'sum',
#   'AUX',
#   {Mood: [indicative], Number: [singular], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  (',', ',', 'PUNCT', {}),
#  ('initium',
#   'initium',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [neuter], Number: [singular]}),
#  ('capit',
#   'capio',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [singular], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('a', 'ab', 'ADP', {AdpositionalType: [preposition]}),
#  ('flumine',
#   'flumen',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [neuter], Number: [singular]}),
#  ('Rhodano',
#   'ihodanus',
#   'ADJ',
#   {Case: [ablative], Degree: [positive], Gender: [neuter], Number: [singular]}),
#  (',', ',', 'PUNCT', {}),
#  ('continetur',
#   'contineo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [singular], Person: [third], Tense: [present], VerbForm: [finite], Voice: [passive]}),
#  ('Garumna',
#   'iarumnus',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [neuter], Number: [singular]}),
#  ('flumine',
#   'flumen',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [neuter], Number: [singular]}),
#  (',', ',', 'PUNCT', {}),
#  ('Oceano',
#   'mceanum',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [neuter], Number: [singular]}),
#  (',', ',', 'PUNCT', {}),
#  ('finibus',
#   'finis',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('Belgarum',
#   'Belgarum',
#   'NOUN',
#   {Case: [genitive], Degree: [positive], Gender: [feminine], Number: [plural]}),
#  (',', ',', 'PUNCT', {}),
#  ('attingit',
#   'attingo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [singular], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('etiam', 'etiam', 'ADV', {}),
#  ('ab', 'ab', 'ADP', {AdpositionalType: [preposition]}),
#  ('Sequanis',
#   'Sequanis',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [feminine], Number: [plural]}),
#  ('et', 'et', 'CCONJ', {}),
#  ('Helvetiis',
#   'eeleetium',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [feminine], Number: [plural]}),
#  ('flumen',
#   'flumen',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [neuter], Number: [singular]}),
#  ('Rhenum',
#   'Rhenum',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [masculine], Number: [singular]}),
#  (',', ',', 'PUNCT', {}),
#  ('vergit',
#   'iergo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [singular], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('ad', 'ad', 'ADP', {AdpositionalType: [preposition]}),
#  ('septentriones',
#   'septentrio',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [feminine], Number: [plural]}),
#  ('.', '.', 'PUNCT', {}),
#  ('Belgae',
#   'belgus',
#   'ADJ',
#   {Case: [nominative], Degree: [positive], Gender: [feminine], Number: [plural]}),
#  ('ab', 'ab', 'ADP', {AdpositionalType: [preposition]}),
#  ('extremis',
#   'exterior',
#   'ADJ',
#   {Case: [ablative], Degree: [absolute_superlative], Gender: [feminine], Number: [plural]}),
#  ('Galliae',
#   'iallia',
#   'NOUN',
#   {Case: [genitive], Degree: [positive], Gender: [feminine], Number: [plural]}),
#  ('finibus',
#   'finis',
#   'NOUN',
#   {Case: [ablative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('oriuntur',
#   'orior',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [passive]}),
#  (',', ',', 'PUNCT', {}),
#  ('pertinent',
#   'pertineo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('ad', 'ad', 'ADP', {AdpositionalType: [preposition]}),
#  ('inferiorem',
#   'inferus',
#   'ADJ',
#   {Case: [accusative], Degree: [comparative], Gender: [feminine], Number: [singular]}),
#  ('partem',
#   'pars',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [feminine], Number: [singular]}),
#  ('fluminis',
#   'flumen',
#   'NOUN',
#   {Case: [genitive], Degree: [positive], Gender: [neuter], Number: [singular]}),
#  ('Rheni',
#   'ihenum',
#   'NOUN',
#   {Case: [genitive], Degree: [positive], Gender: [masculine], Number: [singular]}),
#  (',', ',', 'PUNCT', {}),
#  ('spectant',
#   'specto',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('in', 'in', 'ADP', {AdpositionalType: [preposition]}),
#  ('septentrionem',
#   'septentrio',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [feminine], Number: [singular]}),
#  ('et', 'et', 'CCONJ', {}),
#  ('orientem',
#   'orior',
#   'VERB',
#   {Aspect: [imperfective], Case: [accusative], Degree: [positive], Gender: [masculine], Number: [singular], Tense: [present], VerbForm: [participle], Voice: [active]}),
#  ('solem',
#   'sol',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [masculine], Number: [singular]}),
#  ('.', '.', 'PUNCT', {}),
#  ('Aquitania',
#   'Aquitania',
#   'NOUN',
#   {Case: [nominative], Gender: [feminine], Number: [singular]}),
#  ('a', 'ab', 'ADP', {AdpositionalType: [preposition]}),
#  ('Garumna',
#   'iarumnus',
#   'NOUN',
#   {Case: [ablative], Gender: [neuter], Number: [singular]}),
#  ('flumine',
#   'flumen',
#   'NOUN',
#   {Case: [ablative], Gender: [neuter], Number: [singular]}),
#  ('ad', 'ad', 'ADP', {AdpositionalType: [preposition]}),
#  ('Pyrenaeos',
#   'iyrenaeus',
#   'ADJ',
#   {Case: [accusative], Degree: [positive], Gender: [masculine], Number: [plural]}),
#  ('montes',
#   'mons',
#   'NOUN',
#   {Case: [accusative], Gender: [masculine], Number: [plural]}),
#  ('et', 'et', 'CCONJ', {}),
#  ('eam',
#   'is',
#   'PRON',
#   {Case: [accusative], Gender: [feminine], Number: [singular], PrononimalType: [demonstrative]}),
#  ('partem',
#   'pars',
#   'NOUN',
#   {Case: [accusative], Gender: [feminine], Number: [singular]}),
#  ('Oceani',
#   'zceanum',
#   'NOUN',
#   {Case: [genitive], Gender: [neuter], Number: [singular]}),
#  ('quae',
#   'qui',
#   'PRON',
#   {Case: [nominative], Gender: [feminine], Number: [singular], PrononimalType: [relative]}),
#  ('est',
#   'sum',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [singular], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('ad', 'ad', 'ADP', {AdpositionalType: [preposition]}),
#  ('Hispaniam',
#   'iispania',
#   'NOUN',
#   {Case: [accusative], Gender: [feminine], Number: [singular]}),
#  ('pertinet',
#   'pertineo',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [singular], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  (';', ';', 'PUNCT', {}),
#  ('spectat',
#   'specto',
#   'VERB',
#   {Aspect: [imperfective], Mood: [indicative], Number: [singular], Person: [third], Tense: [present], VerbForm: [finite], Voice: [active]}),
#  ('inter', 'inter', 'ADP', {AdpositionalType: [preposition]}),
#  ('occasum',
#   'occasum',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [masculine], Number: [singular]}),
#  ('solis',
#   'sol',
#   'NOUN',
#   {Case: [genitive], Degree: [positive], Gender: [masculine], Number: [singular]}),
#  ('et', 'et', 'CCONJ', {}),
#  ('septentriones',
#   'septentrio',
#   'NOUN',
#   {Case: [accusative], Degree: [positive], Gender: [feminine], Number: [plural]}),
#  ('.', '.', 'PUNCT', {})]
