# %% [markdown]
# # Diagrams Overview
#
# One piece generate document workflows allow for the creation of materials containing a wide variety of simple diagrams produced from simple text descriptions contained withing the body of the document.
#
# Making changes to the diagram simply requires a change to the original text description of it. When the document is reflowed, the diagram will be directly updated. There is no distance between the source material and the rendered diagram. The source material contains the description of the diagram and rendered directly from it.
#
# By providing learners with tools of production related to diagram generation, we also make it easier for them to create their own diagrams and explore appropriate visual ways of supporting their own learning.
#
# Several package exists that support the generation of diagrams from simple text descriptions of them. Through the creation of simple magics, we can use cell block magic to configure a code cell to accept these various description types and then render diagrams directly from them.
#
# By including the the textual generator script in the source document, output assets can be generated in situ. Updating or maintaining the inages takes place in the context within which the asset is used, minimising opportunities for the asset and the surrounding text context to become disjointed.
#
# The availability of simple text descriptions of a diagram, from which diagrams are typically rendered according to a fixed convention (although layout algorithms may determine the specific location of diagram components within a particular diagram) might also be used as mimimally sufficient text description of many key features of the diagram.
#
# Currently, meaningful human readable "long description" text descriptions to support accessibility are *not* generated from the original generative text descritptions, but the potential is there for such development if the will is there to exploit it.

# %% [markdown]
# ## Blockdiag Package Diagrams
#
# The [`blockdiag`](http://blockdiag.com/en/) package provides tools for generating several types of diagram, from simple box and arrows diagrams to various disgrams familiar to communications and system engineers.
#
# The diagrams are defined using simple text structures. Various IPython block magics allow these descriptions to be entered direclty in to a magicked code cell, and the diagram generated diectly therefrom.
#
# The diagrams are generated by default as SVG diagrams and can be saved to a named file if requierd; `.png `format images may also be created.
#
# All the magics are enabled from a single load command:

# %%
# %load_ext blockdiag_magic

# %% [markdown]
# ### Block Diagrams

# %%
# %%blockdiag
# A -> B -> C;
# B -> D;

# %% [markdown]
# ### Network Diagrams
#
# TO DO

# %% [markdown]
# In the following diagram, we save the SVG image to an explicit file as an additional output. (The direct output is hidden using a publishing system tag in the original soruce document.)

# %%
# %%nwdiag --outfile demo1.svg
# {
#   network dmz {
#       address = "210.x.x.x/24"
#
#       web01 [address = "210.x.x.1"];
#       web02 [address = "210.x.x.2"];
#   }
#   network internal {
#       address = "172.x.x.x/24";
#
#       web01 [address = "172.x.x.1"];
#       db01;
#       app01;
#   }
# }

# %% [markdown]
# We can then explictly render the image, from the saved file, as required:

# %%
from IPython.display import SVG
SVG('demo1.svg')

# %%
## 

#%pip install git+https://github.com/innovationOUtside/flowchart_js_jp_proxy_widget
# Out:
# Collecting git+https://github.com/innovationOUtside/flowchart_js_jp_proxy_widget
#   Cloning https://github.com/innovationOUtside/flowchart_js_jp_proxy_widget to /private/var/folders/l8/qg6m44156_l6bzv_cbkk7bf00000gn/T/pip-req-build-5rit74xp
#   Running command git clone -q https://github.com/innovationOUtside/flowchart_js_jp_proxy_widget /private/var/folders/l8/qg6m44156_l6bzv_cbkk7bf00000gn/T/pip-req-build-5rit74xp
# Requirement already satisfied: jp_proxy_widget in /usr/local/lib/python3.9/site-packages (from jp-flowchartjs==0.0.1) (1.0.8)
# Requirement already satisfied: cairosvg in /usr/local/lib/python3.9/site-packages (from jp-flowchartjs==0.0.1) (2.5.1)
# Requirement already satisfied: cairocffi in /usr/local/lib/python3.9/site-packages (from cairosvg->jp-flowchartjs==0.0.1) (1.2.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/site-packages (from cairosvg->jp-flowchartjs==0.0.1) (1.1.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/site-packages (from cairosvg->jp-flowchartjs==0.0.1) (8.1.0)
# Requirement already satisfied: cssselect2 in /usr/local/lib/python3.9/site-packages (from cairosvg->jp-flowchartjs==0.0.1) (0.4.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/site-packages (from cairosvg->jp-flowchartjs==0.0.1) (0.6.0)
# Requirement already satisfied: cffi>=1.1.0 in /usr/local/lib/python3.9/site-packages (from cairocffi->cairosvg->jp-flowchartjs==0.0.1) (1.14.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/site-packages (from cffi>=1.1.0->cairocffi->cairosvg->jp-flowchartjs==0.0.1) (2.20)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/site-packages (from cssselect2->cairosvg->jp-flowchartjs==0.0.1) (0.5.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.9/site-packages (from jp_proxy_widget->jp-flowchartjs==0.0.1) (7.6.3)
# Requirement already satisfied: jupyter-ui-poll in /usr/local/lib/python3.9/site-packages (from jp_proxy_widget->jp-flowchartjs==0.0.1) (0.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from jp_proxy_widget->jp-flowchartjs==0.0.1) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from jp_proxy_widget->jp-flowchartjs==0.0.1) (2.25.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.9/site-packages (from ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.9/site-packages (from ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (5.1.2)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/site-packages (from ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (5.0.5)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/site-packages (from ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (7.19.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/site-packages (from ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/site-packages (from ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (5.4.3)
# Requirement already satisfied: appnope in /usr/local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.1.2)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (6.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (6.1.11)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (56.0.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (3.0.18)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (2.7.4)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (4.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/site-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.8.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (4.7.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (3.2.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/Cellar/protobuf/3.15.8/libexec/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.17.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (6.3.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (20.1.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.9.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (2.11.2)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (5.6.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (22.0.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.9/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (1.1.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (3.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (20.8)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->jp_proxy_widget->jp-flowchartjs==0.0.1) (2.4.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->jp_proxy_widget->jp-flowchartjs==0.0.1) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/site-packages (from requests->jp_proxy_widget->jp-flowchartjs==0.0.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->jp_proxy_widget->jp-flowchartjs==0.0.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->jp_proxy_widget->jp-flowchartjs==0.0.1) (2020.12.5)
# Building wheels for collected packages: jp-flowchartjs
#   Building wheel for jp-flowchartjs (setup.py) ... done
#   Created wheel for jp-flowchartjs: filename=jp_flowchartjs-0.0.1-py3-none-any.whl size=3890 sha256=805b2c738e21e40e0cd36a114ec4f2c810ef68c0bf12fac80a20414a31d5fa99
#   Stored in directory: /private/var/folders/l8/qg6m44156_l6bzv_cbkk7bf00000gn/T/pip-ephem-wheel-cache-onx15i0n/wheels/5d/18/5b/da85aaa6b010ea90648c64920d1f16476a3e09fd7b632f985d
# Successfully built jp-flowchartjs
# Installing collected packages: jp-flowchartjs
# Successfully installed jp-flowchartjs-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import the `jp_flowchartjs` package, which automatically registers the magic:

# %%
import jp_flowchartjs.jp_flowchartjs

# %% [markdown]
# We can now create simpe description of the flow chart and render it directly:

# %%
# %%flowchart_magic
#
# st=>start: Start
# e=>end: End
# op1=>operation: Generate
# op2=>parallel: Evaluate
# st(right)->op1(right)->op2
# op2(path1, top)->op1
# op2(path2, right)->e
# Out:
# FlowchartWidget(status='deferring flush until render')

# %% [markdown]
# We can also create more complext flowcharts:

# %%
# %%flowchart_magic
# st=>start: Start
# e=>end: End
# op1=>operation: Set counter to 0
# op2=>operation: Draw side code
# op3=>operation: Turn ninety degrees code
# op4=>operation: Add 1 to counter
# cond=>condition: Is counter < 4?
# st(right)->op1(right)->op2->op3->cond
# cond(yes, right)->op2
# cond(no, bottom)->e
# Out:
# FlowchartWidget(status='deferring flush until render')

# %% [markdown]
# ## Other js Diagramming Tools
#
# A variety of javascript based text to diagram tools exist that are not currently natively supported by Jupyer notebook extensions or magics. However, if the will were there, it should not be too hard to make them play nicely with Jupyer notebooks in a similar way to the examples provided above.
#
# - [`js-sequence-diagrams`](https://bramp.github.io/js-sequence-diagrams/);
# - [`mermaid.js`](https://mermaid-js.github.io/mermaid/#/)
# - [timing diagrams](https://wavedrom.com/)
# - supporting diagramming generation via markdown fenced code blocks using [*Markdown preview enhancdd*](https://shd101wyy.github.io/markdown-preview-enhanced/#/) VS Code extension.
